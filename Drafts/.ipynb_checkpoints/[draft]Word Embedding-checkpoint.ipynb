# %% [markdown]
# Chinese Word Emedding

# %%
# first install wget 
# !pip install wget
# Out:
# Collecting wget
#   Using cached wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=9ca86404978e3da399637d9f80e77ebd7647ccf15e1acc224e6140c6fd17dbd8
#   Stored in directory: /Users/randgrant/Library/Caches/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
# Calculation
import numpy as np
import re

# Chinese NLP
import jieba
import stopwordsiso
from stopwordsiso import stopwords

# Showing Result
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Word Vector
import nltk
from gensim.models.keyedvectors import KeyedVectors
from gensim.models.word2vec import Word2Vec
import codecs

# %%
#Run this every time you run the notebook (if working on your own computer)
embeddings_file = "sgns.weibo.word.bz2"
#This line will load the 200,000 most common words into wv, a variable of word vectors
#Note that this will load these into memory, so if you don't have a lot of memory on your computer you may run into problems/slowness
wv = KeyedVectors.load_word2vec_format(embeddings_file, binary=False, limit=200000)

# %% [markdown]
# ## Chinese Word Vector Examples

# %%
#View the actual value of a vector for a word:
# this is a 300-dimensional vector
print("Shape of a word vector: ")
print(np.shape(wv['language'])) #play around with other words
print("Word vector for '她们':")
print(wv['她们'])
# Out:
# Shape of a word vector:
# (300,)
# Word vector for '她们':
# [ 0.103229  0.262013  0.260333  0.256208  0.053925  0.029112  0.046635
#   0.037861  0.048672  0.14674   0.235704  0.166753  0.009411 -0.012865
#   0.010915  0.255409 -0.06188  -0.281446  0.676499 -0.238047  0.063596
#  -0.06598   0.167279  0.104832  0.014178  0.093726 -0.016231  0.172963
#   0.126681 -0.12017  -0.086508 -0.356151  0.265634 -0.166346 -0.049017
#   0.079614  0.009738 -0.069898 -0.551576  0.134538 -0.138498 -0.043751
#  -0.115721  0.138382  0.445095 -0.209368  0.348714  0.05857  -0.215899
#   0.163844 -0.206939  0.298285 -0.033482  0.192324  0.178568 -0.119193
#  -0.047684  0.059463  0.039447 -0.233447 -0.174795  0.099283 -0.22532
#  -0.224391  0.403765 -0.134041 -0.115816 -0.296303  0.376629  0.013709
#  -0.051973 -0.096273  0.317882  0.058543  0.186186 -0.094611  0.185952
#   0.240657 -0.057203  0.115495 -0.151155  0.072935  0.132072  0.017737
#   0.193661  0.12266   0.270064  0.009574 -0.240214 -0.164152  0.033018
#   0.271672  0.13189   0.233629  0.008947  0.127141  0.077017  0.078565
#   0.15479  -0.332627  0.123153  0.123527 -0.281336 -0.307612 -0.555431
#   0.012315 -0.134507  0.364153  0.370319 -0.041092  0.239399  0.138874
#   0.216254 -0.056031  0.024415 -0.32196   0.262287  0.010384 -0.262119
#  -0.157295 -0.017332  0.174301  0.447878 -0.385797  0.02426   0.14709
#   0.143894  0.307196  0.043057 -0.242397 -0.330016 -0.004336 -0.043639
#  -0.210163 -0.112531 -0.226547 -0.020479 -0.230866  0.22507  -0.3724
#   0.165675  0.125445  0.30099  -0.041375 -0.07089   0.052715 -0.07243
#   0.028417  0.185485 -0.134227  0.043898  0.253278  0.060165  0.140355
#   0.111065  0.185498 -0.131746 -0.195962  0.053763  0.033312 -0.064947
#  -0.34836   0.132403  0.460898 -0.026205  0.015396  0.015819  0.490287
#   0.086547 -0.245721 -0.30518   0.125162  0.007371 -0.034797  0.119889
#   0.013987  0.108161  0.118447 -0.256107  0.130922  0.183691 -0.265688
#  -0.007474  0.158725  0.301206  0.243643  0.071854 -0.135414 -0.468053
#  -0.20969   0.166297 -0.089685  0.025566  0.049479  0.080687 -0.159513
#  -0.253909 -0.117964  0.003955 -0.289437 -0.113686  0.207227  0.039301
#   0.16934   0.30485   0.118592 -0.808217 -0.199435 -0.17005  -0.072213
#  -0.096712 -0.034285  0.170305  0.235986  0.012705 -0.123739  0.300967
#  -0.042648 -0.270553 -0.405734  0.016746  0.117567 -0.094786 -0.094306
#   0.089965 -0.480163 -0.007449  0.097145 -0.40283  -0.045092  0.109542
#   0.118409 -0.137475 -0.263977 -0.093808 -0.113303  0.342622  0.039163
#   0.254651 -0.110168  0.002306 -0.050485  0.020899 -0.010095  0.227179
#  -0.233575 -0.158854 -0.039018  0.103622 -0.029569 -0.122348 -0.08889
#   0.011281  0.129792  0.173421 -0.192079  0.205997  0.139517  0.100766
#  -0.230304  0.028101 -0.158994 -0.170406  0.29564  -0.117153 -0.066754
#  -0.027063 -0.146614 -0.030503  0.25358  -0.200582  0.236711 -0.039295
#   0.220377  0.079328 -0.596775 -0.01839   0.019976  0.023746  0.226764
#  -0.165415 -0.084874  0.157542  0.070712 -0.231988 -0.057598 -0.183355
#  -0.221564  0.172326  0.303509 -0.215918 -0.263049  0.029391 -0.014564
#  -0.177316 -0.223036  0.221775 -0.517991 -0.400469  0.048491]

# %%
#We can compare words by computing their cosine similarity
# Try this out for different word pairs:
print(wv.similarity('人', '动物'))
print(wv.similarity('人', '男士'))
print(wv.similarity('人', '女士'))
# Out:
# 0.17915054
# 0.17841144
# 0.16730349

# %%
# Look for most similar words to a given word
#Try this out for different words
wv.most_similar(positive=['人'])
# Out:
# [('中国人', 0.45035773515701294),
#  ('令人同情', 0.438035786151886),
#  ('不跟人', 0.42575734853744507),
#  ('丑人俊', 0.4257080852985382),
#  ('得人', 0.41410529613494873),
#  ('曾让我', 0.4113842248916626),
#  ('低三下四', 0.41079458594322205),
#  ('都是人', 0.4102144241333008),
#  ('人心叵测', 0.4101538062095642),
#  ('数人', 0.40981408953666687)]

# %%
wv.most_similar(positive=['网购', '快递']) #Or maybe Camberwell?
# Out:
# [('4008111111', 0.6679229736328125),
#  ('EMS', 0.6668504476547241),
#  ('送货员', 0.6378894448280334),
#  ('快递公司', 0.6275048851966858),
#  ('申通', 0.6231832504272461),
#  ('ems', 0.6225036382675171),
#  ('运单', 0.6195290684700012),
#  ('陆运', 0.6192419528961182),
#  ('爆仓', 0.6125563979148865),
#  ('平邮', 0.6107132434844971)]

# %%
wv.most_similar(positive=['淘宝', '京东']) #Or maybe Camberwell?
# Out:
# [('京东商城', 0.6866937279701233),
#  ('易讯', 0.680483341217041),
#  ('易迅网', 0.669683575630188),
#  ('易迅', 0.6558387875556946),
#  ('一淘', 0.6486860513687134),
#  ('电器城', 0.6275861859321594),
#  ('苏宁', 0.6251825094223022),
#  ('苏宁国美', 0.6244820952415466),
#  ('191亿', 0.6196848750114441),
#  ('etao', 0.6134917140007019)]

# %% [markdown]
# ## t-SNE (within corpus)

# %%
# Code referenced & edited from NLP-Week2.1-Lecture

def Chinese_tokeniser(doc):
    #Split on spaces
    tokens = jieba.lcut(doc)
    processed = []
    for t in tokens:
        #Remove Chinese stop words
        if not t in stopwords("zh"):
            processed = processed + [t]
    #Return an array of tokens for that document
    return processed

# %%
import matplotlib.font_manager as fm
import matplotlib

# %%
font_path = "/Users/randgrant/Downloads/SourceHanSansCN-Normal.otf"
prop = fm.FontProperties(fname = font_path)

# %%
# From https://www.kaggle.com/jeffd23/visualizing-word-vectors-with-t-sne
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.index_to_key:
        tokens.append(model.wv[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom',
                     fontproperties=prop,
                     size=14)
    plt.show()

# %%
#Read back in
file_name = "DOUBAN_dataset"
post_df = pd.read_csv(file_name + ".tsv",sep = "\t", usecols = ["title","link","main text","reply text"])

douban_all_text = []
for index in range(len(post_df)):
    #add title
    all_text = "" + str(post_df.iloc[index][0])
    #add main text
    for main in post_df.iloc[index][2]:
        all_text = all_text + str(main)
    for reply in post_df.iloc[index][3]:
        all_text = all_text + str(reply)
    douban_all_text.append(all_text)

# %%
douban_all_text_token = []
for every_post in douban_all_text:
    douban_all_text_token.append(Chinese_tokeniser(every_post))
douban_all_text_token
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/r1/zv_cgpdj61b8c60j_yk8lx900000gn/T/jieba.cache
# Loading model cost 0.628 seconds.
# Prefix dict has been built successfully.
# [['女',
#   '领导',
#   'pua',
#   '套路',
#   '一次次',
#   '面前',
#   '上演',
#   '[',
#   "'",
#   '领导',
#   '一个个',
#   '套路',
#   '温良',
#   '小白兔',
#   '主动',
#   '996',
#   '\\',
#   'n',
#   '令',
#   '眼界',
#   '大开',
#   '\\',
#   'n',
#   '主动',
#   '分享',
#   '圈里人',
#   '互动',
#   ' ',
#   '\\',
#   'n',
#   '证明',
#   '人脉',
#   '广',
#   '\\',
#   'n',
#   '再来',
#   '亲昵',
#   '喊',
#   '子',
#   '调侃',
#   '日常',
#   '\\',
#   'n',
#   '拉进',
#   '关系',
#   '\\',
#   'n',
#   '外加',
#   '笑眯眯',
#   '对接',
#   '人员',
#   '关系',
#   '升温',
#   '炒作',
#   '暧昧关系',
#   '\\',
#   'n',
#   '最后',
#   '主动',
#   '送',
#   '回家',
#   '吃饭',
#   '约',
#   '游玩',
#   '反复',
#   '洗脑',
#   '\\',
#   'n',
#   '\\',
#   'n',
#   '觉察',
#   '不太对',
#   ' ',
#   '累',
#   '\\',
#   'n',
#   '关怀备至',
#   '1v1',
#   '对谈',
#   '\\',
#   'n',
#   '尖锐',
#   '指出',
#   '工作',
#   '问题',
#   '“',
#   '不能',
#   '~',
#   '”',
#   '\\',
#   'n',
#   '随即',
#   '回顾',
#   '职业',
#   '经历',
#   '传道',
#   '解惑',
#   '时时刻刻',
#   '一副',
#   '“',
#   '姐妹',
#   '你好',
#   '”',
#   '样子',
#   '\\',
#   'n',
#   '最后',
#   '鼓励',
#   '再三',
#   ':',
#   '“',
#   '其实',
#   '蛮',
#   '改改',
#   '刚才',
#   '行',
#   '”',
#   '\\',
#   'n',
#   "'",
#   ']',
#   '[',
#   "'",
#   '一毛',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '一毛',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '有过之无不及',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '一毛',
#   '+',
#   '1',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '警惕',
#   '女',
#   '领导',
#   '女同事',
#   "'",
#   ']'],
#  ['收集',
#   ' ',
#   '同级',
#   '同事',
#   'pua',
#   ' ',
#   ' ',
#   'tm',
#   '🤢',
#   '[',
#   "'",
#   '哈哈哈',
#   'lz',
#   '最近',
#   '经历',
#   '同级',
#   '同事',
#   'pua',
#   '注意',
#   '同级',
#   '同事',
#   '上司',
#   '呦',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '想必',
#   '有人',
#   '相同',
#   '经历',
#   '哈哈哈',
#   '哈哈哈',
#   '聊聊',
#   '留下',
#   '相同',
#   '遭遇',
#   '一起',
#   '吐吐',
#   '槽',
#   "'",
#   ']',
#   '[',
#   "'",
#   '同级',
#   '同事',
#   '指使',
#   '做事',
#   ' ',
#   '说话',
#   '特别',
#   '横',
#   ' ',
#   '命令',
#   '那种',
#   ' ',
#   'pua',
#   ' ',
#   '新人',
#   ' ',
#   '其实',
#   '工人',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '情况',
#   '解决',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '刚',
#   '发现',
#   '原来',
#   'PUA',
#   ',',
#   ' ',
#   '遭遇',
#   '同事',
#   'PUA',
#   '恶心',
#   "'",
#   ',',
#   ' ',
#   "'",
#   ' ',
#   '同级',
#   ' ',
#   '领导',
#   ' ',
#   '招数',
#   '白',
#   '嫖',
#   '工作',
#   '成果',
#   "'",
#   ']'],
#  ['第一次',
#   '知道',
#   '原来',
#   '一直',
#   'pua',
#   '[',
#   "'",
#   '今天',
#   '同事',
#   '正面',
#   '杠',
#   '哭',
#   '早上',
#   '出去',
#   '喝',
#   '朋友',
#   '喝酒',
#   '聊天',
#   '朋友',
#   '告诉',
#   '了解',
#   '一下',
#   '职场',
#   'pua',
#   '看过',
#   '文',
#   '以后',
#   '原来',
#   '一直',
#   'pua',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '进入',
#   '国企',
#   '财务',
#   '助理',
#   '以后',
#   '一直',
#   '谨小慎微',
#   '觉得',
#   '半路出家',
#   '小白',
#   '谦虚',
#   '勤快',
#   '眼色',
#   '找',
#   '活干',
#   '安排',
#   '工作',
#   '毫无',
#   '怨言',
#   '很多',
#   '工作',
#   '超出',
#   '能力',
#   '范围',
#   '提出',
#   '太',
#   '懂',
#   '这方面',
#   '会计',
#   '强硬',
#   '告诉',
#   '不会',
#   '学呀',
#   '锻炼',
#   '事情',
#   '干',
#   '不好',
#   '是不是',
#   '愿意',
#   '干',
#   '工作',
#   '…',
#   '…',
#   '久而久之',
#   '拼命',
#   '认为',
#   '问题',
#   '能力',
#   '不行',
#   '我要',
#   '多学',
#   '干',
#   '不停',
#   '年轻人',
#   '多干点',
#   '工作',
#   '多劳多得',
#   '其实',
#   '最低',
#   '层',
#   '工资',
#   '会计',
#   '面前',
#   '觉得',
#   '应该',
#   '更少',
#   '天天',
#   '高薪',
#   '摸鱼',
#   '玩',
#   '手机',
#   '特别',
#   '善于',
#   '伪装',
#   '一副',
#   '天天',
#   '特别',
#   '忙',
#   '样子',
#   '情况',
#   '持续',
#   '三年',
#   '内心',
#   '煎熬',
#   '不停',
#   '怀疑',
#   '是不是',
#   '原因',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '直到现在',
#   '单位',
#   '高层',
#   '发生',
#   '变化',
#   '工作',
#   '调整',
#   '分开',
#   '出纳',
#   '原以为',
#   '轻松',
#   '一点',
#   '挂点',
#   '勾',
#   '扔给',
#   '今天',
#   '安排',
#   '事情',
#   '工作',
#   '特别',
#   '直接',
#   '领导',
#   '领导',
#   '告状',
#   '愿意',
#   '听',
#   '领导',
#   '找',
#   '先',
#   '干',
#   '回来',
#   '觉得很有',
#   '必要',
#   '会计',
#   '谈谈',
#   '高高在上',
#   '进行',
#   '一通',
#   '洗脑',
#   '觉得',
#   '没有',
#   '集体',
#   '荣誉感',
#   '财务',
#   '工作',
#   '工作',
#   '工作',
#   '一定',
#   '会计',
#   '活',
#   '应该',
#   '一起',
#   '完成',
#   '工作',
#   '态度',
#   '问题',
#   '转变',
#   '领导',
#   '工资',
#   '翻倍',
#   '事情',
#   '同事',
#   '讲',
#   '不止一次',
#   '面前',
#   '情绪',
#   '激动',
#   '领导',
#   '工资',
#   '太高',
#   '配有',
#   '高',
#   '工资',
#   '干',
#   '工作',
#   '对得起',
#   '这份',
#   '工资',
#   '觉得',
#   '工作量',
#   '没有',
#   '达到',
#   '饱和',
#   '状态',
#   '完全',
#   '见缝插针',
#   '干些',
#   '工作',
#   '没有',
#   '危机感',
#   '难道',
#   '三十多岁',
#   '一直',
#   '干',
#   '出纳',
#   '学习',
#   '知识',
#   '一直',
#   '干会',
#   '以前',
#   '同事',
#   '干完',
#   '工作',
#   '干',
#   '完',
#   '觉得',
#   '以前',
#   '同事',
#   '工作',
#   '态度',
#   '相当',
#   '其实',
#   '以前',
#   '同事',
#   '搞',
#   '走',
#   '领导',
#   '面前',
#   '同事',
#   '贴票',
#   '不会',
#   '两个',
#   '同事',
#   '多忙',
#   '忙',
#   '干',
#   '工作',
#   '利索',
#   '真的',
#   '怼',
#   '哑口无言',
#   '觉得',
#   '一无是处',
#   '好差',
#   '应该',
#   '争',
#   '错',
#   '应该',
#   '工作',
#   '干',
#   '现在',
#   '领导',
#   '干',
#   '工作',
#   '难过',
#   '办公室',
#   '哭',
#   '好久',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '单位',
#   '受尽',
#   '这种',
#   '方式',
#   '压迫',
#   '无数次',
#   '怀疑',
#   '崩溃',
#   '自我',
#   '痊愈',
#   "'",
#   ']',
#   '[',
#   "'",
#   '遇到',
#   '这种',
#   '情况',
#   '仗',
#   '公司',
#   '资历',
#   '派活儿',
#   '老同志',
#   '脸色',
#   '出言不逊',
#   '遇到',
#   '干活',
#   '情况',
#   '躲到',
#   '茶水',
#   '间',
#   '闲聊',
#   '厕所',
#   '看得',
#   '习惯',
#   '这种',
#   '习惯',
#   '代表',
#   '逆来顺受',
#   '接受',
#   '这种',
#   'pua',
#   '思考',
#   '巧妙',
#   '办法',
#   '应对',
#   '办法',
#   '觉得',
#   '见招拆招',
#   '每次',
#   '肯定',
#   '这是',
#   '新',
#   '课题',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '反击',
#   '脸色',
#   '特别',
#   '理解',
#   '难',
#   '想着',
#   '工作',
#   '真的',
#   '很多',
#   '领导',
#   '找',
#   '老实',
#   '忙',
#   '真的',
#   '没',
#   '办法',
#   '偷懒',
#   '重要',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '嘴笨',
#   '每次',
#   '怼',
#   '哑口无言',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '有时候',
#   '想',
#   '踏踏实实',
#   '干',
#   '工作',
#   '就行',
#   '现在',
#   '办公室',
#   '太极拳',
#   '工作',
#   '重要',
#   '一部分',
#   '觉得',
#   '上班',
#   '好难',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '同情',
#   '~',
#   ' ',
#   '加油',
#   '卷',
#   'si',
#   "'",
#   ']'],
#  ['明',
#   '知道',
#   '这是',
#   'PUA',
#   ' ',
#   '有点',
#   '无法',
#   '逃离',
#   '[',
#   "'",
#   '组里',
#   '豆油',
#   '付出',
#   '回报',
#   '美其名曰',
#   '锻炼',
#   '应该',
#   '逃跑',
#   '工作',
#   '偶尔',
#   '实在',
#   '清闲',
#   '有事',
#   '收入',
#   '尚可',
#   '到底',
#   '该不该',
#   '辞职',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '有时候',
#   '受够了',
#   '上司',
#   '自以为是',
#   '教导',
#   '比较',
#   '言语',
#   '之间',
#   '透露',
#   '傲慢',
#   '偏见',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '不想',
#   '任何人',
#   '交流',
#   '只想',
#   '事',
#   "'",
#   ']',
#   '[',
#   "'",
#   '完全',
#   '不想',
#   '扯淡',
#   "'",
#   ']'],
#  ['记',
#   '一次',
#   '成功',
#   '返',
#   '职场',
#   'PUA',
#   '[',
#   "'",
#   '记录',
#   '启迪',
#   "'",
#   ']',
#   '[',
#   "'",
#   '需要',
#   '内容',
#   '组长',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '创建',
#   '话题',
#   ' ',
#   '哈哈哈',
#   "'",
#   ']'],
#  ['领导',
#   'pua',
#   '半年',
#   '怀疑',
#   '[',
#   "'",
#   '入职',
#   '半年',
#   '刚',
#   '面试',
#   '领导',
#   '花言巧语',
#   '骗来',
#   '想',
#   '办法',
#   '员工',
#   '争取',
#   '充足',
#   '弹药',
#   '同伴',
#   '放心',
#   '打仗',
#   '领导',
#   '入职',
#   '之后',
#   '发现',
#   '面试',
#   '沟通',
#   '完全',
#   '一致',
#   '岗位',
#   '职能',
#   '非常',
#   '混乱',
#   '5',
#   '内容',
#   '方向',
#   '一份',
#   '工作',
#   '独立',
#   '带',
#   '团队',
#   '这份',
#   '工作',
#   '之后',
#   '没有',
#   '一天',
#   '正儿八经',
#   '内容',
#   '每天',
#   '拓展',
#   '新',
#   '渠道',
#   '开',
#   '店铺',
#   '走',
#   '流程',
#   '打杂',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '领导',
#   '隔三差五',
#   '找我聊',
#   '天',
#   '能力',
#   '不行',
#   '内容',
#   '不值钱',
#   '转',
#   '方向',
#   '好好',
#   '想想',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '每次',
#   '领导',
#   '聊',
#   '完天',
#   '缓',
#   '好久',
#   '打气',
#   '加油',
#   '恢复过来',
#   '半年',
#   '真的',
#   '磨',
#   '非常',
#   '讨厌',
#   '工作',
#   '每天',
#   '上班',
#   '地铁',
#   '觉得',
#   '压抑',
#   '喘',
#   '过来',
#   '气',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '最可气',
#   '领导',
#   '没关系',
#   '不出',
#   '成绩',
#   '养着',
#   '一直',
#   '就让',
#   '不想',
#   '发展',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '每天',
#   '上班',
#   '上坟',
#   '现在',
#   '想',
#   '辞职',
#   '怕',
#   '真的',
#   '所说',
#   '找',
#   '不到',
#   '工作',
#   '太难',
#   '…',
#   '…',
#   "'",
#   ']',
#   '[',
#   "'",
#   'pua',
#   '完后',
#   '怀疑',
#   '是不是',
#   '真的',
#   '适合',
#   '干',
#   '这行',
#   '同事',
#   '业绩',
#   '相差',
#   '同事',
#   '夸',
#   '不错',
#   '不错',
#   '唯独',
#   '一直',
#   '被贬',
#   '一无是处',
#   ' ',
#   '现在',
#   '离职',
#   '已经',
#   '怀疑',
#   '能力',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '抱抱',
#   '没有勇气',
#   '辞职',
#   '挣扎',
#   "'",
#   ']'],
#  ['拒绝',
#   'pua',
#   '懂',
#   '[',
#   "'",
#   '入职',
#   '半年',
#   '觉得',
#   '我躁',
#   '郁症',
#   '老板',
#   '一无是处',
#   '看到',
#   '话',
#   '不想',
#   '讲',
#   '面前',
#   '本来',
#   '挺',
#   '正常',
#   '谈话',
#   '居然',
#   '磕巴',
#   '觉得',
#   '一无是处',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '绩效',
#   '面谈',
#   '直接',
#   '回答',
#   '觉得',
#   '一般般',
#   '没有',
#   '特别',
#   '毫无',
#   '意外',
#   '1',
#   '接受',
#   '觉得',
#   '未来',
#   '不会',
#   '加薪',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '运气',
#   '守恒',
#   '肯定',
#   '之前',
#   '运气',
#   '太好了',
#   '之前',
#   '年度',
#   '绩效',
#   '第四',
#   '小组第一',
#   '领导',
#   '爱',
#   '同事',
#   '宠',
#   '客户',
#   '夸',
#   '小可爱',
#   '变成',
#   '眼袋',
#   '面色',
#   '沉',
#   '没',
#   '底气',
#   '渣',
#   '渣',
#   '客户',
#   '喜欢',
#   '觉得',
#   '奉承',
#   '姐姐',
#   '问',
#   '涨薪',
#   '没',
#   '觉得',
#   '挖苦',
#   'tm',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '这种',
#   '情绪',
#   '很久没',
#   '听到',
#   '夸奖',
#   '起来',
#   '成立',
#   '夸夸',
#   '群',
#   '分享',
#   '日常',
#   '一起',
#   '赞美',
#   '告别',
#   '苦闷',
#   "'",
#   ',',
#   ' ',
#   "'",
#   'vx',
#   'fdcstar2021',
#   "'",
#   ']',
#   '[',
#   "'",
#   '每天',
#   'PUA',
#   '半年',
#   '怀疑',
#   '觉得',
#   '😶',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '换',
#   '情绪',
#   '认识',
#   '新',
#   '朋友',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '加油',
#   '现在',
#   '进步',
#   '好多',
#   '需要',
#   '认可',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '加油',
#   "'",
#   ',',
#   ' ',
#   "'",
#   'hhhhhhhh',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '好笑',
#   '心酸',
#   '眼泪',
#   "'",
#   ']'],
#  ['目前',
#   '工作',
#   '找到',
#   '最好',
#   '工作',
#   '找',
#   '不到',
#   '更好',
#   '工作',
#   '是否是',
#   'PUA',
#   '[',
#   "'",
#   ' ',
#   ' ',
#   ' ',
#   '女',
#   '肢体',
#   '残疾',
#   '主要',
#   '表现',
#   '走路',
#   '步态',
#   '稳',
#   '走路',
#   '方便',
#   '学历',
#   '医学类',
#   '大专',
#   '目前',
#   '工作',
#   '所学',
#   '专业',
#   '毫无关系',
#   '前提',
#   '谈话',
#   '领导',
#   '多次',
#   '目前',
#   '工作',
#   '应该',
#   '找到',
#   '最好',
#   '工作',
#   '应该',
#   '找',
#   '不到',
#   '适合',
#   '更好',
#   '工作',
#   '算不算',
#   'PUA',
#   '.',
#   "'",
#   ']',
#   '[',
#   "'",
#   '算',
#   '变相',
#   '贬低',
#   "'",
#   ']'],
#  ['昨天',
#   '绩效',
#   '面谈',
#   '领导',
#   'pua',
#   '[',
#   "'",
#   '领导',
#   '那种',
#   '只会',
#   '挑',
#   '缺点',
#   '讲',
#   '从没',
#   '嘴里',
#   '听过',
#   '一句',
#   '夸人',
#   '好话',
#   '绩效',
#   '方方面面',
#   '扣',
#   '明明',
#   '多倍',
#   '工作',
#   '否定',
#   '否定',
#   '当初',
#   '调整',
#   '绩效',
#   '承诺',
#   '没',
#   '实现',
#   '整一个',
#   '失望',
#   '倒霉',
#   '刚',
#   '毕业',
#   '遇到',
#   '领导',
#   '搞',
#   '工作',
#   '一点',
#   '热情',
#   '还给',
#   '搞',
#   '很多',
#   '任务',
#   '…',
#   '…',
#   '这位',
#   '领导',
#   'pua',
#   '完人',
#   '发',
#   '心情',
#   '愉悦',
#   '朋友圈',
#   '差点',
#   '整吐',
#   '以前',
#   '觉得',
#   '挺',
#   '现在',
#   '真的',
#   '一点',
#   '人格魅力',
#   '眼中',
#   '下属',
#   '帮',
#   '组',
#   '干活',
#   '天经地义',
#   '狗',
#   '狗',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '是不是',
#   '公司',
#   '没钱发',
#   '年终',
#   '想',
#   '办法',
#   '压低',
#   '绩效',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '气死',
#   '想',
#   '扎',
#   '小人',
#   "'",
#   ']',
#   '[',
#   ']'],
#  ['离职',
#   '两个',
#   '多月',
#   '意识',
#   '可能',
#   '职场',
#   'PUA',
#   '[',
#   "'",
#   '说实话',
#   '觉得',
#   '现在',
#   '没',
#   '走出',
#   '怪圈',
#   ' ',
#   '开发',
#   ' ',
#   '之前',
#   '一家',
#   '外',
#   '包',
#   '公司',
#   ' ',
#   '刚',
#   '一周',
#   '加班',
#   '四天',
#   ' ',
#   '没有',
#   '加班费',
#   ' ',
#   '当时',
#   '觉得',
#   '工资',
#   '还行',
#   '想着',
#   '接受',
#   ' ',
#   '后期',
#   '出差',
#   ' ',
#   '出差',
#   '以后',
#   '基本上',
#   '天天',
#   '十二点',
#   ' ',
#   '一两点',
#   '通宵',
#   ' ',
#   '公司',
#   '人事',
#   '反应',
#   '情况',
#   ' ',
#   '后来',
#   '奖金',
#   '补偿',
#   ' ',
#   '过度',
#   '劳累',
#   '一天',
#   '直接',
#   '犯',
#   '呼吸',
#   '过度',
#   '送到',
#   '医院',
#   ' ',
#   '说实话',
#   '当时',
#   '真心',
#   '觉得',
#   '无助',
#   ' ',
#   '外地',
#   '送到',
#   '医院',
#   '进行',
#   '吸氧',
#   ' ',
#   '外包',
#   '领导',
#   '不想',
#   '承担责任',
#   ' ',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '后来',
#   '实在',
#   '觉得',
#   '下去',
#   '不行',
#   ' ',
#   '走',
#   '离职',
#   ' ',
#   '离职',
#   '人事',
#   '行业',
#   '辛苦',
#   ' ',
#   '承受',
#   '不了',
#   '其实',
#   '考虑',
#   '换',
#   '行业',
#   '发展',
#   ' ',
#   '当时',
#   '说实话',
#   '身心',
#   '疲惫',
#   ' ',
#   '无力',
#   '反驳',
#   ' ',
#   '后来',
#   '在家',
#   '休息',
#   ' ',
#   '每天',
#   '学习',
#   '想',
#   '找',
#   '工作',
#   ' ',
#   '想到',
#   '再次',
#   '面试',
#   '工作',
#   '潜意识',
#   '里',
#   '排斥',
#   ' ',
#   '现在',
#   '出门',
#   '接触',
#   '大量',
#   '人群',
#   '排斥',
#   '心理',
#   ' ',
#   '感觉',
#   '人事',
#   '公司',
#   'PUA',
#   ' ',
#   '调整',
#   "'",
#   ']',
#   '[',
#   "'",
#   '相信',
#   '运气',
#   '守恒定律',
#   '公司',
#   '领导',
#   '一定',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '奥利',
#   'ଘ',
#   '(',
#   '੭',
#   'ˊ',
#   '꒳',
#   'ˋ',
#   ')',
#   '੭',
#   '✧',
#   "'",
#   ',',
#   ' ',
#   "'",
#   'pua',
#   '出去',
#   '走走',
#   '朋友',
#   '聊聊',
#   '内心',
#   '想法',
#   '写',
#   '下来',
#   '需要',
#   '宣泄',
#   '一下',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '加油',
#   '领导',
#   '肯定',
#   '超级',
#   '公司',
#   '加油',
#   "'",
#   ']'],
#  ['深夜',
#   '睡不着',
#   '终于',
#   '意识',
#   '职场',
#   'pua',
#   '[',
#   "'",
#   '前提',
#   '公司',
#   '毕业',
#   '工作',
#   '公司',
#   '最难',
#   '已经',
#   '七八年',
#   '今天',
#   '中午',
#   '问',
#   '老板',
#   '工作',
#   '分配不公',
#   '不行',
#   '当时',
#   '一句',
#   '话',
#   '没',
#   '怼',
#   '回去',
#   '现在',
#   '回想起来',
#   '全是',
#   '恶心',
#   '太',
#   '怂',
#   '太',
#   '包子',
#   '千万',
#   '句',
#   '否定',
#   '谈话',
#   '过程',
#   '一句',
#   '不提',
#   '功劳',
#   '苦劳',
#   '打些',
#   '名义',
#   '一直',
#   '打击',
#   '自信',
#   '搞',
#   '久',
#   '自我',
#   '怀疑',
#   '上升',
#   '私生活',
#   '朋友',
#   '不好',
#   '正面',
#   '影响',
#   '朋友',
#   '明明',
#   '难道',
#   '朋友',
#   '天天',
#   '劝',
#   '公司',
#   '服务',
#   '加班',
#   '熬夜',
#   '成',
#   '活该',
#   '现在',
#   '看来',
#   '真是',
#   '活该',
#   '卖命',
#   '天天',
#   '累',
#   '应该',
#   '大钱',
#   '挣',
#   '挣',
#   '几千',
#   '操心',
#   '公司',
#   '本来',
#   '一份',
#   '工资',
#   '身兼数职',
#   '太',
#   '恶心',
#   '吐',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '太',
#   '难过',
#   '想起',
#   '恶心',
#   '话',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '工作',
#   '大不了',
#   '没',
#   '收入',
#   '几个',
#   '舍不得',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '职场',
#   'pua',
#   '解释',
#   '一条',
#   '没',
#   '落下',
#   '现在',
#   '觉得',
#   '悲哀',
#   "'",
#   ']',
#   '[',
#   "'",
#   '抱抱',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '😭',
#   '😭',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '同感',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '离职',
#   '之后',
#   '经常',
#   '怂',
#   '懊恼',
#   '当时',
#   '应该',
#   '怼',
#   '回去',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '现在',
#   '经常',
#   '事',
#   '恶心',
#   '每个',
#   '平台',
#   '骂',
#   '一遍',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '赶紧',
#   '走人',
#   '新',
#   '公司',
#   '两个',
#   '积极性',
#   '一点点',
#   '磨灭',
#   '产生',
#   '严重',
#   '自我',
#   '怀疑',
#   '职场',
#   'pua',
#   '太',
#   '可怕',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '打着',
#   '你好',
#   '名号',
#   '实则',
#   '却是',
#   '想',
#   '操控',
#   '干涉',
#   '…',
#   '…',
#   "'",
#   ']'],
#  ['每天',
#   '总结',
#   '主管',
#   'pua',
#   '话术',
#   '[',
#   "'",
#   '1',
#   '想',
#   '不想',
#   '挑战',
#   '一下',
#   '复杂',
#   '没有',
#   '意义',
#   '事情',
#   '安排',
#   '身上',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '2',
#   '没',
#   '挑战',
#   '已经',
#   '做过',
#   '成长',
#   '资源',
#   '方法',
#   '提供',
#   '就让',
#   '不好',
#   '慢',
#   '挨批',
#   "'",
#   ']',
#   '[',
#   "'",
#   '3',
#   '.',
#   ' ',
#   '马路上',
#   '随便',
#   '找',
#   '找个',
#   'intern',
#   '工作',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '6',
#   '.',
#   ' ',
#   '最近',
#   '有人',
#   '表达',
#   '不满',
#   '不能',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '【',
#   '周末',
#   '有事',
#   '请假',
#   '】',
#   '2020',
#   '听',
#   '震撼',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '5',
#   '.',
#   ' ',
#   'XX',
#   '强',
#   'XX',
#   '专科',
#   '学历',
#   '部门',
#   '之前',
#   '岗位',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '太',
#   '敏感',
#   '太',
#   '情绪化',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '3',
#   '.',
#   ' ',
#   '马路上',
#   '随便',
#   '找',
#   '找个',
#   'intern',
#   '工作',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '4',
#   '想',
#   '不想',
#   '是不是',
#   '想',
#   '干',
#   'xx',
#   '岗位',
#   '指在',
#   '主管',
#   '看来',
#   '\\',
#   'nLow',
#   '逼',
#   '岗位',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '5',
#   '.',
#   ' ',
#   'XX',
#   '强',
#   'XX',
#   '专科',
#   '学历',
#   '部门',
#   '之前',
#   '岗位',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '6',
#   '.',
#   ' ',
#   '最近',
#   '有人',
#   '表达',
#   '不满',
#   '不能',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '两个',
#   '前',
#   '遇到',
#   '情况',
#   '几乎',
#   '一字不差',
#   '…',
#   '…',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '【',
#   '周末',
#   '有事',
#   '请假',
#   '】',
#   '2020',
#   '听',
#   '震撼',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '似曾相识',
#   '感觉',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '能力',
#   '太差',
#   '一点',
#   '价值',
#   '没有',
#   '滚',
#   '辞职信',
#   '交上来',
#   '辞职',
#   '外面',
#   '找',
#   '不到',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '太',
#   '敏感',
#   '太',
#   '情绪化',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '晋升',
#   '走',
#   '行业',
#   '里',
#   '名声',
#   '臭',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '去年',
#   '碰到',
#   '这种',
#   '版本',
#   '”',
#   'team',
#   '里面',
#   '其他人',
#   '投诉',
#   '“',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '这份',
#   '工作',
#   '保证',
#   '找到',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '再也不会',
#   '遇到',
#   '两个',
#   '经理',
#   '经理',
#   '照顾',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '现在',
#   '辅助性',
#   '工作',
#   '觉得',
#   '压力',
#   '负责',
#   '板块',
#   '工作',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '需要',
#   '继续',
#   '锻炼',
#   '抗压',
#   '能力',
#   '不行',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '没有',
#   '学历',
#   '技能',
#   '公司',
#   '锻炼',
#   '机会',
#   '好好',
#   '珍惜',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '好好',
#   '干',
#   '明年',
#   '争取',
#   '调薪',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '有没有',
#   '觉得',
#   'xxx',
#   '以前',
#   '岗位',
#   '辞退',
#   '同事',
#   '好好',
#   '想',
#   '一下',
#   "'",
#   ']'],
#  ['知道',
#   '算不算',
#   '职场',
#   'PUA',
#   '但烦',
#   '不可',
#   '耐',
#   '[',
#   "'",
#   '没有',
#   '海外',
#   '留学',
#   '经历',
#   '工作',
#   '第三年',
#   '没有',
#   '海外',
#   '留学',
#   '想法',
#   '领导',
#   '三番五次',
#   '给我发',
#   '海外',
#   '留学',
#   '工作',
#   '好处',
#   '婉拒',
#   '已经',
#   '做好',
#   '下一代',
#   '牺牲',
#   '准备',
#   '言下之意',
#   '父母',
#   '不够',
#   '牺牲',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '经常',
#   '发',
#   '拍照',
#   '穿',
#   '搭',
#   '经常',
#   '发',
#   '泳装',
#   '泳衣',
#   '自信',
#   '穿',
#   '上级',
#   '男',
#   '领导',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '已知',
#   '家庭',
#   '条件',
#   '经常',
#   '家',
#   '那片',
#   '房价',
#   '竟然',
#   '高',
#   '房价',
#   '要降',
#   ',',
#   '问',
#   '家庭收入',
#   '大城市',
#   '找',
#   '工作',
#   '留在',
#   '家乡',
#   '陪',
#   '父母',
#   '已经',
#   '浪费',
#   '两年',
#   '直接',
#   '否定',
#   '职场',
#   '两年',
#   '付出',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '知道',
#   '是不是',
#   '职场',
#   'PUA',
#   '真的',
#   '不堪',
#   '其扰',
#   '打扰',
#   '见谅',
#   "'",
#   ']',
#   '[',
#   "'",
#   '不要',
#   '理',
#   '生活',
#   'PUA',
#   '羡慕',
#   '嫉妒',
#   '父母',
#   '家',
#   '分开',
#   "'",
#   ']'],
#  ['知道',
#   '是不是',
#   'pua',
#   '[',
#   "'",
#   '1',
#   '.',
#   '题主是',
#   '今年',
#   '刚',
#   '毕业',
#   '应届生',
#   '入职',
#   '三个',
#   '多月',
#   '公司',
#   '分配',
#   '前辈',
#   '带',
#   '主要',
#   '跟着',
#   '项目',
#   '前辈',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '2',
#   '.',
#   '介绍',
#   '一下',
#   '前辈',
#   '情况',
#   '前辈',
#   '工作',
#   '十一年',
#   '今年',
#   '刚',
#   '跳槽',
#   '就职',
#   '这家',
#   '公司',
#   '没有',
#   '领导',
#   '头衔',
#   '部门',
#   '分小组',
#   '制',
#   '每个',
#   '组',
#   '组长',
#   '领导',
#   '领导',
#   '没有',
#   '上下级',
#   '关系',
#   '极其',
#   '喜欢',
#   '命令',
#   '指令',
#   '做事',
#   '周末',
#   '几点',
#   '加班',
#   '几点',
#   '吃完饭',
#   "'",
#   ',',
#   ' ',
#   "'",
#   "'",
#   ',',
#   ' ',
#   "'",
#   ' ',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '3',
#   '.',
#   '前辈',
#   '喜欢',
#   '骂',
#   '脏话',
#   '“',
#   'wo',
#   ' ',
#   'cao',
#   '”',
#   '“',
#   'cao',
#   '”',
#   '“',
#   'tamade',
#   '”',
#   '“',
#   'shabi',
#   '”',
#   '曾经',
#   '东西',
#   '“',
#   'cao',
#   '”',
#   '“',
#   '服',
#   '”',
#   '那会入',
#   '职',
#   '不到',
#   '半个',
#   "'",
#   ',',
#   ' ',
#   "'",
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '今天',
#   '加班',
#   '凌晨',
#   '五点',
#   '怪',
#   '慢',
#   '大喊大叫',
#   '弄出来',
#   '大喊',
#   '“',
#   '”',
#   '亲自',
#   '手',
#   '操作',
#   '成功',
#   '骂',
#   '“',
#   'cao',
#   '”',
#   'shabi',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '错误',
#   '导致',
#   '今天',
#   '工时',
#   '加上',
#   '有人',
#   '导致',
#   '今天',
#   '加班',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '4',
#   '.',
#   '“',
#   '懂',
#   '”',
#   '“',
#   '耽误时间',
#   '”',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '“',
#   '干什么',
#   '不行',
#   '”',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '5',
#   '.',
#   '“',
#   '过来',
#   '”',
#   '“',
#   '”',
#   '从未',
#   '称呼',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '6',
#   '.',
#   '懂',
#   '问',
#   '不要',
#   '不懂装懂',
#   '每次',
#   '反问',
#   '翻白眼',
#   '转脸',
#   '一边',
#   '喷气',
#   '撇嘴',
#   '不耐烦',
#   '“',
#   '听',
#   '明白',
#   '”',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '7',
#   '.',
#   '每天',
#   '早上',
#   '上班',
#   '命令式',
#   '带',
#   '不耐烦',
#   '布置任务',
#   '没',
#   '听',
#   '明白',
#   '问',
#   '问题',
#   '复述',
#   '一遍',
#   '想要',
#   '确认',
#   '一次',
#   '喷气',
#   '撇嘴',
#   '翻白眼',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '8',
#   '.',
#   '同事',
#   '客气',
#   '颐指气使',
#   '经常',
#   '早',
#   '上班',
#   '多干点',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '9',
#   '.',
#   '要求',
#   '甲方',
#   '指出',
#   '要求',
#   '改',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '10',
#   '.',
#   '晚上',
#   '加班',
#   '出去',
#   '吃饭',
#   '催',
#   "'",
#   ',',
#   ' ',
#   "'",
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '11',
#   '.',
#   '一次',
#   '数据线',
#   '掉',
#   '捡起来',
#   '“',
#   '数据线',
#   '真丑',
#   '”',
#   '普通',
#   '白色',
#   'type',
#   '—',
#   'c',
#   '数据线',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '\\',
#   'n',
#   "'",
#   ']',
#   '[',
#   "'",
#   '快',
#   '找',
#   '下家',
#   '这种',
#   '人远',
#   '一点',
#   "'",
#   ',',
#   ' ',
#   "'",
#   ' ',
#   '这种',
#   '傻',
#   '逼',
#   "'",
#   ']'],
#  ['实习',
#   '职场',
#   'pua',
#   '经历',
#   '[',
#   "'",
#   '互联网',
#   '中厂',
#   '品牌',
#   '策划',
#   '刚入',
#   '职',
#   '星期',
#   'leader',
#   '每天',
#   '进行',
#   'pua',
#   '经常',
#   '期望',
#   '特别',
#   '高',
#   '要求',
#   '严格',
#   '严师',
#   '出',
#   '高徒',
#   '屁话',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '"',
#   '主要',
#   ' ',
#   '老师',
#   '\\',
#   'n',
#   '不能',
#   '一直',
#   '想着',
#   ' ',
#   '我来',
#   '监督',
#   '解决',
#   '问题',
#   '\\',
#   'n',
#   ' ',
#   '之前',
#   '方案',
#   '参考',
#   '\\',
#   'n',
#   '咱俩',
#   '是不是',
#   '0',
#   '默契',
#   '\\',
#   'n',
#   '一句',
#   '话',
#   ' ',
#   '感觉',
#   ' ',
#   '解释',
#   '半天',
#   '懂',
#   '...',
#   '\\',
#   'n',
#   '有个',
#   '弟弟',
#   '昨晚',
#   '加班',
#   '10',
#   ' ',
#   '今天',
#   '10',
#   '点前',
#   ' ',
#   '以后',
#   '注意',
#   '"',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '算是',
#   '比较',
#   '自觉',
#   '热爱工作',
#   '完全',
#   '没有',
#   '摸鱼',
#   '划水',
#   '之前',
#   '每次',
#   '实习',
#   '没遇',
#   '这种',
#   '处处',
#   '挑刺',
#   '愿意',
#   '输出',
#   '负',
#   '能量',
#   '上司',
#   '大不了',
#   '几岁',
#   '一边',
#   '实习生',
#   '配合',
#   '一边',
#   '当纯',
#   '工具',
#   '压榨',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '可怕',
#   '知道',
#   '回怼',
#   '有时候',
#   '怀疑',
#   '真的',
#   '能力',
#   '问题',
#   "'",
#   ']',
#   '[',
#   "'",
#   '感觉',
#   '咱俩',
#   '情况',
#   '好像',
#   '带',
#   '实习生',
#   '正式',
#   '员工',
#   '干',
#   '完',
#   '成就',
#   '加班',
#   '…',
#   '…',
#   '几天',
#   '整',
#   '压抑',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '能力',
#   '上来',
#   '更好',
#   '使唤',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '感觉',
#   '咱俩',
#   '情况',
#   '好像',
#   '带',
#   '实习生',
#   '正式',
#   '员工',
#   '干',
#   '完',
#   '成就',
#   '加班',
#   '…',
#   '…',
#   '几天',
#   '整',
#   '压抑',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '能力',
#   '上来',
#   '更好',
#   '使唤',
#   "'",
#   ',',
#   ' ',
#   "'",
#   'woc',
#   '带',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '一摸',
#   '样子',
#   '抱头痛哭',
#   '.',
#   'jpg',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '一模一样',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '情况',
#   '有点像',
#   '现在',
#   '太',
#   '难过',
#   '正在',
#   '办公室',
#   '哭',
#   '菜',
#   '😅',
#   "'",
#   ',',
#   ' ',
#   "'",
#   'pua',
#   '是因为',
#   '太',
#   '过于',
#   '重视',
#   '某位',
#   '领导',
#   '说法',
#   '调整',
#   '心态',
#   '有错就改',
#   '没错',
#   '当场',
#   '提出',
#   '质疑',
#   '领导',
#   '看人下菜',
#   '挑',
#   '软柿子',
#   '捏',
#   "'",
#   ']'],
#  ['今天',
#   '无端',
#   '指控',
#   '做事',
#   '负责',
#   '无头无尾',
#   '[',
#   "'",
#   '事情',
#   '样子',
#   '9',
#   '月初',
#   '总部',
#   '会计',
#   '离职',
#   '接手',
#   '手上',
#   '2',
#   '家',
#   '公司',
#   '当时',
#   '正当',
#   '月初',
#   '出财报',
#   '时间',
#   '相当',
#   '紧迫',
#   '原先',
#   '工作',
#   '5',
#   '家',
#   '子公司',
#   '已经',
#   '每天',
#   '饱和',
#   '工作',
#   '状态',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '心里',
#   '头',
#   '自然',
#   '太',
#   '愿意',
#   '没',
#   '办法',
#   '秉着',
#   '顾全大局',
#   '想法',
#   '经理',
#   '分配',
#   '下来',
#   '先',
#   '后期',
#   '问题',
#   '进行',
#   '讨论',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '交接',
#   '之后',
#   '一遍',
#   '工作',
#   '内容',
#   '交接',
#   '资料',
#   '确认',
#   '无误',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '原来',
#   '负责',
#   '5',
#   '家',
#   '再加',
#   '2',
#   '家',
#   '确实',
#   '搞',
#   '过来',
#   '主管',
#   '每月',
#   '开发票',
#   '这块',
#   '不能',
#   '找',
#   '交接',
#   '没有',
#   '得到',
#   '回复',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '期间',
#   '经理',
#   '核对',
#   '欠费',
#   '情况表',
#   '第一',
#   '时间',
#   '核对',
#   '发给',
#   '没有',
#   '权限',
#   '借用',
#   '账号',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '本月',
#   '20',
#   '号',
#   '公司',
#   '架构',
#   '调整',
#   '工作',
#   '重新分配',
#   '开票',
#   '事情',
#   '已经',
#   '接手',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '今天',
#   '愿意',
#   '开发票',
#   '事情',
#   '经理',
#   '约',
#   '话',
#   '不足',
#   '三点',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '1',
#   '做事',
#   '没头没尾',
#   '当时',
#   '交接',
#   '现在',
#   '搞',
#   '半',
#   '干',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '2',
#   '当时',
#   '交接',
#   '不够',
#   '主动',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '3',
#   '责任心',
#   '强',
#   "'",
#   ',',
#   ' ',
#   "'",
#   "'",
#   ',',
#   ' ',
#   "'",
#   '终结',
#   '接手',
#   '不够',
#   '积极',
#   '进',
#   '看重',
#   '缺',
#   '样子',
#   '辜负',
#   '领导',
#   '信任',
#   '交接',
#   '适应期',
#   '要求',
#   '非常',
#   '完美',
#   '速度',
#   '快',
#   '立马',
#   '数据',
#   '现在',
#   '愿意',
#   '弄',
#   '问题',
#   '责任心',
#   '强',
#   '不够',
#   '团结',
#   '想着',
#   '事儿',
#   "'",
#   ']',
#   '[',
#   ']'],
#  ['突然',
#   '意识',
#   '对面',
#   'pua',
#   '[',
#   "'",
#   '工作',
#   '瞬间',
#   '发现',
#   '这人',
#   'pua',
#   '白',
#   '嫖',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '留言',
#   '职场',
#   '小白',
#   '提醒',
#   "'",
#   ',',
#   ' ',
#   "'",
#   "'",
#   ',',
#   ' ',
#   "'",
#   '先',
#   '现',
#   '公司',
#   '合伙人',
#   '新',
#   '投资',
#   '实体店',
#   '前期',
#   '帮帮忙',
#   '觉得',
#   '尼玛',
#   '真是',
#   '免费',
#   '劳动力',
#   '不爽',
#   '认为',
#   '帮忙',
#   '觉得',
#   '店长',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '至此',
#   '整体',
#   '形象',
#   '分数',
#   '下滑',
#   '最近',
#   '准备',
#   '分家',
#   '创业',
#   '2',
#   '伙伴',
#   "'",
#   ']',
#   '[',
#   "'",
#   '典型',
#   '楼主',
#   '那种',
#   '做事',
#   '应得',
#   '报酬',
#   '机会',
#   '锻炼',
#   "'",
#   ']'],
#  ['知道',
#   '算不算',
#   'pua',
#   '发泄',
#   '或许',
#   '好点',
#   '[',
#   "'",
#   '自尊心',
#   '蛮强',
#   '脸皮',
#   '厚',
#   '领导',
#   '批评',
#   '倒',
#   '觉得',
#   '话',
#   '太',
#   '重伤',
#   '竟然',
#   '每次',
#   '冷言冷语',
#   '找到',
#   '几丝',
#   '确实',
#   '改正',
#   '改善',
#   '地方',
#   '搞',
#   '心里',
#   '难受',
#   '觉得',
#   '没',
#   '做好',
#   '思考',
#   '不好',
#   '混成',
#   '这种',
#   '反思',
#   '找到',
#   '问题',
#   '后能',
#   '落实',
#   '行动',
#   '无疑',
#   '进步',
#   '变得',
#   '优秀',
#   '暂时',
#   '没有',
#   '特别',
#   '心态',
#   '压力',
#   '化为',
#   '动力',
#   '最近',
#   '时常',
#   '深陷',
#   '这种',
#   '痛苦',
#   '一天',
#   '醒',
#   '脑子里',
#   '循环',
#   '播放',
#   '领导',
#   '今天',
#   '批评',
#   '猜测',
#   '明天',
#   '理由',
#   '批评',
#   '感觉',
#   '快',
#   '自闭',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '领导',
#   '风格',
#   '大概',
#   '昨天',
#   '周末',
#   '早上',
#   '出门',
#   '医院',
#   '检查',
#   '身体',
#   '突然',
#   '接到',
#   '领导',
#   '电话',
#   '弄',
#   '东西',
#   '说明',
#   '情况',
#   '医院',
#   '可能',
#   '晚点',
#   '回',
#   '算了',
#   '先',
#   '看看',
#   '半小时',
#   '左右',
#   '发',
#   '信息',
#   '不用',
#   '回',
#   '无法',
#   '及时处理',
#   '临时',
#   '工作',
#   '表示',
#   '抱歉',
#   '讲真',
#   '在家',
#   '周末',
#   '肯定',
#   '爬起来',
#   '弄',
#   '医院',
#   '可能',
#   '办法',
#   '处理',
#   '今天',
#   '事情',
#   '劈头盖脸',
#   '一顿',
#   '骂',
#   '包括',
#   '昨天',
#   '这件',
#   '事',
#   '工作',
#   '主动性',
#   '不够',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '事情',
#   '已经',
#   '不想',
#   '回想',
#   '整个',
#   '很致郁',
#   '以前',
#   '领导',
#   '讨厌',
#   '比较',
#   '讲武',
#   '德',
#   '背后',
#   '吐槽',
#   '能够',
#   '吐得',
#   '一顿',
#   '骂娘',
#   '畅快',
#   '现在',
#   '不行',
#   '不行',
#   '想到',
#   '感觉',
#   '毁',
#   '一天',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '入职',
#   '一个月',
#   '已经',
#   '影响',
#   '心情',
#   '生活',
#   '事',
#   '没',
#   '兴趣',
#   '六神无主',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '救命',
#   "'",
#   ']',
#   '[',
#   "'",
#   '说个',
#   '搞笑',
#   '今天',
#   '同事',
#   '一起',
#   '吐槽',
#   '太难',
#   '懂',
#   '天才',
#   '不会',
#   '挨骂',
#   '同事',
#   '领导',
#   '那天',
#   '\\',
#   'n',
#   '没有',
#   '哭',
#   '笑',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '😭',
#   '天',
#   '简直',
#   '一模一样',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '一模一样',
#   '😭',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '天天',
#   '天天',
#   '骂',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '摸头',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '坚强',
#   '不哭',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '休息',
#   '休息',
#   '领导',
#   '信息',
#   '不要',
#   '回',
#   '看到',
#   '1',
#   '小时',
#   '简单',
#   '回复',
#   '…',
#   '…',
#   '\\',
#   'n',
#   '职场',
#   '8',
#   '清楚',
#   '领导',
#   'PUA',
#   "'",
#   ',',
#   ' ',
#   "'",
#   'CS',
#   '很多',
#   '企业',
#   '…',
#   '…',
#   '领导',
#   '欺软怕硬',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '一次',
#   '下班',
#   '准点',
#   '走',
#   '日常',
#   '班车',
#   '理由',
#   '正当',
#   '有事',
#   '发现',
#   '没',
#   '遂',
#   '打电话',
#   '开头',
#   '不爽',
#   '“',
#   '跑',
#   '快',
#   '一看',
#   '没有',
#   '”',
#   '之后',
#   '事',
#   '记上',
#   '隔三差五',
#   '拿出',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '领导',
#   '妥妥',
#   'pua',
#   "'",
#   ']'],
#  ['领导',
#   'pua',
#   '失眠',
#   '现在',
#   '[',
#   "'",
#   '现在',
#   '一家',
#   '商场',
#   '里',
#   '市场营销部',
#   '工作',
#   ',',
#   '主要',
#   '负责',
#   '工作',
#   '内容',
#   '平面设计',
#   '学历',
#   '高',
#   '应届',
#   '毕业',
#   '很多',
#   '事情',
#   '新',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '平时',
#   '接',
#   '平面',
#   '相关',
#   '私活',
#   '主',
#   '画面',
#   '设计',
#   'logo',
#   '设计',
#   '包装',
#   '设计',
#   '前两天',
#   '领导',
#   '约',
#   '谈',
#   ',',
#   ' ',
#   '话',
#   '里',
#   '话',
#   '外',
#   '嫌弃',
#   '学历',
#   '低',
#   '专科',
#   '设计',
#   '专业',
#   '毕业',
#   '嫌弃',
#   '能力',
#   '不够',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '认为',
#   '能力',
#   '相较',
#   '老同事',
#   '差',
#   '一点',
#   '这份',
#   '工作',
#   '出去',
#   '大部分',
#   '时间',
#   '繁琐',
#   '跑量',
#   '美工',
#   '类',
#   '工作',
#   '岗位',
#   '负责',
#   '小红书',
#   '运营',
#   '仓库',
#   '人手',
#   '不够',
#   '搬运',
#   '东西',
#   '工作室',
#   '十四五个',
#   '小时',
#   '常有',
#   '事',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '领导',
#   '告诉',
#   '表面工夫',
#   '不够',
#   '足',
#   '装',
#   '装',
#   '在职',
#   '场',
#   '想',
#   '安静',
#   '设计',
#   '同事',
#   '喜欢',
#   '素材',
#   '网站',
#   '东西',
#   '拼接',
#   '一起',
#   '现在',
#   '没有',
#   '学到',
#   '东西',
#   '工作量',
#   '很少',
#   '原创',
#   '内容',
#   '输出',
#   '同事',
#   '美院',
#   '毕业',
#   '公司',
#   '原创',
#   '手绘',
#   '工作',
#   '负责',
#   'ip',
#   '形象',
#   '全揽',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '现在',
#   '真的',
#   '很困',
#   '痛苦',
#   '之前',
#   '抑郁',
#   '史',
#   '文字',
#   '语音',
#   '转化',
#   '可能',
#   '比较',
#   '罗嗦',
#   '这种',
#   '工作',
#   '月薪',
#   '3000',
#   '块钱',
#   '不到',
#   '领导',
#   '工作',
#   '两个',
#   '半月',
#   '已经',
#   '无数次',
#   '讲',
#   '能力',
#   '不行',
#   '经常',
#   '长篇大论',
#   '发',
#   '语音',
#   '约',
#   '谈',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '私活',
#   '目前',
#   '稳定',
#   '一个月',
#   '最多',
#   '赚',
#   '一千左右',
#   '现在',
#   '人住',
#   '外面',
#   '房租',
#   '1300',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '六个',
#   '小时',
#   '上班',
#   '不出意外',
#   '月底',
#   '辞职',
#   '辞职',
#   '之后',
#   '想',
#   '小红书',
#   '开',
#   '公众',
#   '号',
#   '画',
#   '一下',
#   '公司',
#   '痛苦',
#   '职场',
#   '故事',
#   '真的',
#   '快逃',
#   '不要',
#   '城市',
#   '商场',
#   '工作',
#   "'",
#   ']',
#   '[',
#   "'",
#   '毕业',
#   '一家',
#   '公司',
#   'pua',
#   '现在',
#   '准备',
#   '备考',
#   '硕士',
#   '不出意外',
#   '想',
#   '一直',
#   '读',
#   '博士',
#   '想',
#   '留在',
#   '校园',
#   '老师',
#   '不想',
#   '面对',
#   '公司',
#   '奇葩',
#   '一年',
#   '三观',
#   '已经',
#   '破碎',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '本职工作',
#   '没',
#   '做好',
#   '接',
#   '私活',
#   '精力',
#   '\\',
#   'n',
#   '同事',
#   '拼接',
#   '得学',
#   '拼接',
#   '拼接',
#   '效率',
#   '更高',
#   '\\',
#   'n',
#   '\\',
#   'n',
#   '没有',
#   'PUA',
#   '就事论事',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '确实',
#   '已经',
#   '离职',
#   '考驾照',
#   '心态',
#   '很多',
#   "'",
#   ',',
#   ' ',
#   "'",
#   ' ',
#   '就事论事',
#   '本职工作',
#   '没',
#   '做好',
#   '档期',
#   '前',
#   '平面',
#   '工作',
#   '到位',
#   '原创',
#   '每次',
#   '一稿',
#   '讨厌',
#   '搬',
#   '货去',
#   '推',
#   '做本',
#   '应该',
#   '工作',
#   '99',
#   '现在',
#   '刚',
#   '毕业',
#   '搬出来',
#   '住',
#   '负担',
#   '开销',
#   '这点',
#   '工资',
#   '不接',
#   '私活',
#   '一点',
#   '钱',
#   '存',
#   '下来',
#   '同事',
#   '拼接',
#   '美院',
#   '毕业',
#   '这家',
#   '公司',
#   '四年',
#   '3000',
#   '一个月',
#   '觉得',
#   '安稳',
#   '反正',
#   '已经',
#   '离职',
#   '坚持',
#   '设计',
#   '原创',
#   '为主',
#   '想',
#   '走',
#   '设计师',
#   '这条',
#   '路',
#   '不要',
#   '安排',
#   '美工',
#   '工作',
#   '内容',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '原文',
#   '\\',
#   'n',
#   '领导',
#   '工作',
#   '两个',
#   '半月',
#   '已经',
#   '无数次',
#   '讲',
#   '能力',
#   '不行',
#   '\\',
#   'n',
#   '认为',
#   '能力',
#   '相较',
#   '老同事',
#   '差',
#   '一点',
#   "'",
#   ',',
#   ' ',
#   "'",
#   'pua',
#   '东西',
#   '一稿',
#   '领导',
#   '觉得',
#   '能力',
#   '不行',
#   '觉得',
#   '\\',
#   'n',
#   '当时',
#   '半夜',
#   '发文',
#   '段时间',
#   '发生',
#   '好多',
#   '事情',
#   '领导',
#   '搞',
#   '下来',
#   '离开',
#   '公司',
#   '第一件',
#   '事',
#   '告诉',
#   '能力',
#   '其实',
#   '没有',
#   '不行',
#   '怕',
#   '太',
#   '骄傲',
#   '没有',
#   '清楚',
#   '抱歉',
#   '两个',
#   '前发',
#   '文',
#   '后续',
#   '没有',
#   '补发',
#   '内容',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '博士',
#   '内卷',
#   '严重',
#   '家里',
#   '差钱',
#   '留校',
#   "'",
#   ']'],
#  ['救命',
#   '领导',
#   '突然',
#   '找',
#   '谈话',
#   '换岗',
#   '有没有',
#   '家人',
#   '帮忙',
#   '解读',
#   '啥意思',
#   '[',
#   "'",
#   '事情',
#   '新',
#   '项目',
#   '负责人',
#   '项目组',
#   '第一天',
#   '每个',
#   '单独',
#   '聊',
#   '工作量',
#   '问题',
#   '第二天',
#   '开',
#   '会议',
#   '单独',
#   '谈话',
#   '明确',
#   '工作量',
#   '加',
#   '工作量',
#   '后来',
#   '第三天',
#   '主动',
#   '找',
#   '项目',
#   '负责人',
#   '沟通',
#   '工作',
#   '直接',
#   '领导',
#   '一起',
#   '谈',
#   '今天',
#   '找',
#   '谈',
#   '问',
#   '想',
#   '之前',
#   '部门',
#   '同事',
#   '工作',
#   '问题',
#   '冲突',
#   '后来',
#   '主动',
#   '解决',
#   '直接',
#   '领导',
#   '提',
#   '事情',
#   '一无是处',
#   '最后',
#   '问',
#   '不要',
#   '转岗',
#   '表明',
#   '现在',
#   '工作',
#   '合适',
#   '问问',
#   '项目',
#   '缺不缺',
#   '调过去',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '想',
#   '问下',
#   '应该',
#   '解决',
#   '问题',
#   '刚',
#   '转正',
#   '一个月',
#   "'",
#   ']',
#   '[',
#   ']'],
#  ['难以',
#   '摆脱',
#   '领导',
#   '情绪',
#   '价值',
#   '依赖',
#   '[',
#   "'",
#   '全文',
#   '三千余',
#   '字',
#   '楼主',
#   '多发',
#   '几个',
#   '组求',
#   '骂',
#   '醒',
#   '力图',
#   '情绪稳定',
#   '成年人',
#   '情绪',
#   '自给自足',
#   '有毒',
#   '情绪',
#   '价值',
#   '麻痹',
#   '\\',
#   'n',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   '楼主',
#   '传统',
#   '行业',
#   '工作',
#   '两年',
#   '当年',
#   '找',
#   '工作',
#   '碰',
#   '不少',
#   '壁受',
#   '不少',
#   '打击',
#   '现在',
#   '领导',
#   '校友',
#   '面试',
#   '我招',
#   '进',
#   '公司',
#   '颇为',
#   '感激',
#   '后来',
#   '校友',
#   '成',
#   '师父',
#   '人到',
#   '陌生',
#   '城市',
#   '工作',
#   '很长',
#   '一段时间',
#   '现实',
#   '打交道',
#   '师父',
#   '团队',
#   '在乎',
#   '评价',
#   '希望',
#   '得到',
#   '认可',
#   '入',
#   '职后',
#   '师父',
#   '表现',
#   '出',
#   '关心',
#   '照顾',
#   '愿意',
#   '培养',
#   '态度',
#   '努力',
#   '打杂',
#   '开心',
#   '工作',
#   '这是',
#   '背景',
#   '后来',
#   '逐渐',
#   '意识',
#   '并非如此',
#   '现在',
#   '先',
#   '一一',
#   '控诉',
#   '行为',
#   '疑惑',
#   '清楚',
#   '知道',
#   '欺压',
#   '为人处事',
#   '原则',
#   '之后',
#   '不止',
#   '卖命',
#   '难以',
#   '摆脱',
#   '心理',
#   '依赖',
#   '思维',
#   '逐渐',
#   '清晰',
#   '过程',
#   '意识',
#   '母胎',
#   '单身',
#   '现在',
#   '好事',
#   '工作',
#   'PUA',
#   '至少',
#   '攒',
#   '经验',
#   '攒下',
#   '钱',
#   '碰上',
#   '渣',
#   '男',
#   '同样',
#   '套路',
#   '知道',
#   '卖',
#   '数钱',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   '段时间',
#   '领导',
#   '微信',
#   '一遍',
#   '脑中',
#   '很多',
#   '情景',
#   '一遍',
#   '原先',
#   '“',
#   '意义',
#   '工作',
#   '做出',
#   '一番',
#   '事业',
#   '”',
#   '“',
#   '报答',
#   '师父',
#   '录取',
#   '培养',
#   '顾之恩',
#   '”',
#   '幼稚',
#   '想法',
#   '改成',
#   '“',
#   '打卡',
#   '上班',
#   '领',
#   '工资',
#   '工人',
#   '”',
#   '“',
#   '人际关系',
#   '利益',
#   '为本',
#   '”',
#   '之后',
#   '渐渐',
#   '没有',
#   '之前',
#   '那种',
#   '自我',
#   '加戏',
#   '悲愤',
#   '之感',
#   '明白',
#   '不得志',
#   '小人',
#   '欺软怕硬',
#   '国企',
#   '老',
#   '狐狸精',
#   '秀',
#   '存在',
#   '感',
#   '方式',
#   '没什么',
#   '大不了',
#   '之前',
#   '承受',
#   '巨大',
#   '心理压力',
#   '失眠',
#   '抑郁',
#   '流泪',
#   '毫无意义',
#   '场景',
#   '发生',
#   '那刻',
#   '却是',
#   '真实',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   '\\',
#   'n',
#   '他会',
#   '找',
#   '谈话',
#   '谈',
#   '长时间',
#   '尤其',
#   '刚入',
#   '职',
#   '前半年',
#   '动辄',
#   '一两个',
#   '小时',
#   '快',
#   '憋不住',
#   '厕所',
#   '身为',
#   '下级',
#   '不敢',
#   '贸然',
#   '打断',
#   '中止',
#   '谈话',
#   '难受',
#   '只能',
#   '忍着',
#   '听',
#   '知道',
#   '亲近感',
#   '这种',
#   '谈话',
#   '培养',
#   '不想',
#   '听',
#   '愿意',
#   '听',
#   '一定',
#   '灌进',
#   '耳朵',
#   '里',
#   '\\',
#   'n',
#   '能够',
#   '和蔼',
#   '亲近',
#   '看起来',
#   '实诚',
#   '态度',
#   '谈话',
#   '说话',
#   '语调',
#   '颇为',
#   '印象',
#   '深刻',
#   '后来',
#   '接触',
#   '房产',
#   '中介',
#   '见识',
#   '这种',
#   '语调',
#   '那种',
#   '轻声',
#   '高',
#   '音调',
#   '好像',
#   '呵护',
#   '着想',
#   '语调',
#   '销售',
#   '语调',
#   '甘心',
#   '好好',
#   '技术',
#   '失败',
#   '销售',
#   '自我陶醉',
#   '情商',
#   '高',
#   '语调',
#   '后来',
#   '发现',
#   '哄',
#   '女人',
#   '哄',
#   '情妇',
#   '这种',
#   '语调',
#   '入侵',
#   '性',
#   '强',
#   '细思则',
#   '恶心',
#   '容易',
#   '自我感觉',
#   '良好',
#   '自我感觉',
#   '关系',
#   '很近',
#   '觉得',
#   '拘礼',
#   '防备',
#   '说话',
#   '实际上',
#   '说话',
#   '仍然',
#   '百般',
#   '刻意',
#   '加上',
#   '情商',
#   '只能',
#   '十分钟',
#   '超过',
#   '十分钟',
#   '谈话',
#   '脑子',
#   '宕机',
#   '突破',
#   '防线',
#   '虚假',
#   '表演',
#   '看到',
#   '真实',
#   '反应',
#   '硬',
#   '灌',
#   '下去',
#   '内容',
#   '加上',
#   '大段',
#   '大段',
#   '给我发',
#   '短信',
#   '很受',
#   '关注',
#   '很受',
#   '关心',
#   '感觉',
#   '时间',
#   '精力',
#   '投入',
#   '中年人',
#   '很大',
#   '成本',
#   '上级',
#   '这种',
#   '程度',
#   '关注',
#   '付出',
#   '受宠若惊',
#   '\\',
#   'n',
#   '这种',
#   '谈话',
#   '感受',
#   '很多',
#   '温暖',
#   '逐渐',
#   '产生',
#   '依赖',
#   '一个月',
#   '加班',
#   '加',
#   '最狠',
#   '精神',
#   '快',
#   '扛不住',
#   '怨恨',
#   '最近',
#   '关注',
#   '找',
#   '谈话',
#   '表示',
#   '关心',
#   '已经',
#   '成功',
#   '洗脑',
#   '不用',
#   '继续',
#   '洗',
#   '\\',
#   'n',
#   '\\',
#   'n',
#   '会施',
#   '小恩小惠',
#   '刚来',
#   '技术',
#   '奖励',
#   '一杯',
#   '羹',
#   '表现',
#   '出',
#   '有福同享',
#   '样子',
#   '刚来',
#   '常请',
#   '团队',
#   '吃饭',
#   '后来',
#   '少',
#   '出差',
#   '旅游',
#   '打车',
#   '门票',
#   '不让',
#   '出钱',
#   '义正',
#   '言辞',
#   '语气',
#   '表现',
#   '出',
#   '一点',
#   '占',
#   '徒弟',
#   '便宜',
#   '态度',
#   '后来',
#   '明白',
#   '大概',
#   '途径',
#   '报销',
#   '当时',
#   '就让',
#   '人手',
#   '短',
#   '感觉',
#   '每个',
#   '长假',
#   '反复',
#   '几次',
#   '提前',
#   '回家',
#   '省',
#   '机票',
#   '钱',
#   '其实',
#   '最终',
#   '批准',
#   '碰上',
#   '社会',
#   '事情',
#   '麻烦',
#   '居然',
#   '打听',
#   '信誓旦旦',
#   '认识',
#   '帮',
#   '联系',
#   '最后',
#   '爱莫能助',
#   '\\',
#   'n',
#   '\\',
#   'n',
#   '不要',
#   '急于',
#   '当官',
#   '好好',
#   '修练',
#   '技术',
#   '为本',
#   '高',
#   '期望',
#   '实际上',
#   '没有',
#   '修练',
#   '技术',
#   '机会',
#   '整天',
#   '工作',
#   '不要',
#   '挑挑拣拣',
#   '不要',
#   '不屑于',
#   '打杂',
#   '情商',
#   '低',
#   '不能',
#   '融入',
#   '企业',
#   '文化',
#   '学习',
#   '~',
#   '\\',
#   'n',
#   '情商',
#   '低',
#   '这种',
#   'PUA',
#   '真是',
#   '后知后觉',
#   '早已',
#   '伤痕累累',
#   '看着',
#   '网友',
#   '普及',
#   '慢慢',
#   '明白',
#   '这种',
#   '行为',
#   '相同',
#   '困扰',
#   '朋友',
#   '分享',
#   '知乎',
#   '网友',
#   '回答',
#   '找',
#   '不到',
#   '原文',
#   '侵删',
#   '“',
#   '情商',
#   '低',
#   '父母',
#   '亲戚',
#   '特别',
#   '朋友',
#   '深入探讨',
#   '改进',
#   '领导',
#   '同事',
#   '关系',
#   '无视',
#   '情商',
#   '高',
#   '至少',
#   '人品',
#   '不行',
#   '想',
#   '打压',
#   '方式',
#   '压榨',
#   '价值',
#   '本质',
#   '欺软怕硬',
#   '亲戚',
#   '关系',
#   '极其',
#   '密切',
#   '朋友',
#   '情商',
#   '低',
#   '你好',
#   '站',
#   '有利',
#   '角度',
#   '大概',
#   '没有',
#   '顺从',
#   '感觉',
#   '优越感',
#   '骂',
#   '情商',
#   '低',
#   '觉得',
#   '你好',
#   '欺负',
#   '提高',
#   '情商',
#   '得利',
#   '发展',
#   '没有',
#   '好处',
#   '“',
#   '”',
#   '后来',
#   '发现',
#   '“',
#   '情商',
#   '低',
#   '”',
#   '其实',
#   '想',
#   '表达',
#   '事',
#   '不爽',
#   '情商',
#   '锅',
#   '不爽',
#   '扣',
#   '“',
#   '\\',
#   'n',
#   '\\',
#   'n',
#   '压榨',
#   '新人',
#   '套路',
#   '意思',
#   '这种',
#   '不会',
#   'But',
#   ',',
#   ' ',
#   'I',
#   ' ',
#   'was',
#   ' ',
#   'wrong',
#   '.',
#   '\\',
#   'n',
#   '他会',
#   '笑',
#   '实诚',
#   '善良',
#   '诚实',
#   '这话',
#   '语气',
#   '明显',
#   '嘲笑',
#   '尊重',
#   '团队',
#   '里',
#   '两个',
#   '内向',
#   '保护',
#   '不会',
#   '保护',
#   '答应',
#   '不合理',
#   '安排',
#   '提出',
#   '我别',
#   '实诚',
#   '设计院',
#   '欺负',
#   '一天',
#   '干完',
#   '活说',
#   '两天',
#   '累死',
#   '不会',
#   '耍',
#   '套路',
#   '欺压',
#   '错',
#   '\\',
#   'n',
#   '吃苦耐劳',
#   '型',
#   '跟着',
#   '肯定',
#   '死',
#   '里',
#   '压榨',
#   '反复强调',
#   '不要',
#   '加班',
#   '太过',
#   '平衡',
#   '工作',
#   '生活',
#   '工作',
#   '生活',
#   '好像',
#   '硬',
#   '加班',
#   '劝',
#   '加班',
#   '加班',
#   '不要',
#   '超过',
#   '8',
#   '后来',
#   '加班',
#   '不要',
#   '超过',
#   '9',
#   '后来',
#   '加班',
#   '不要',
#   '超过',
#   '九点半',
#   '越来越',
#   '虚伪',
#   '\\',
#   'n',
#   '\\',
#   'n',
#   '优点',
#   '给我发',
#   '奖金',
#   '同期',
#   '入职',
#   '同事',
#   '稍',
#   '高',
#   '不停',
#   '强调',
#   '一点',
#   '还会',
#   '某某某',
#   '觉得',
#   '收入',
#   '过高',
#   '某某某',
#   '听说',
#   '嫉妒',
#   '还会',
#   '两句',
#   '觉得',
#   '给我发',
#   '得少',
#   '以后',
#   '努力',
#   '规则',
#   '允许',
#   '范围',
#   '内保',
#   '收入',
#   '考虑',
#   '唯',
#   '金钱至上',
#   '猜',
#   '心里',
#   '觉得',
#   '薄',
#   '\\',
#   'n',
#   '刚',
#   '拿到',
#   '工资',
#   '确实',
#   '有点',
#   '慌张',
#   '觉得',
#   '不配',
#   '收入',
#   '肯定',
#   '弄错',
#   '不会',
#   '长久',
#   '后来',
#   '发现',
#   '这是',
#   '普遍现象',
#   '国企',
#   '实际收入',
#   '我入',
#   '职前',
#   '想象',
#   '高',
#   '想',
#   '理由',
#   '怀疑',
#   '利用',
#   '一点',
#   '捧杀',
#   '\\',
#   'n',
#   '一笔',
#   '去年',
#   '年底',
#   '奖金',
#   '本是',
#   '准备',
#   '今年年初',
#   '发',
#   '本来',
#   '时间',
#   '没到',
#   '项目',
#   '里',
#   '前辈',
#   '去年',
#   '收入',
#   '挺高',
#   '想',
#   '这笔',
#   '奖金',
#   '放在',
#   '今年',
#   '避税',
#   '领导',
#   '三番五次',
#   '刚来',
#   '收入',
#   '不算',
#   '太高',
#   '需要',
#   '避税',
#   '打算',
#   '先',
#   '发',
#   '婉拒',
#   '不用',
#   '特地',
#   '麻烦',
#   '提前',
#   '发',
#   '继续',
#   '奖金',
#   '单让',
#   '签字',
#   '看着',
#   '上面',
#   '数额',
#   '觉得',
#   '周围',
#   '不好',
#   '多问',
#   '直接',
#   '签了',
#   '奖金',
#   '单',
#   '扫描',
#   '发给',
#   '他供',
#   '上传',
#   '之后',
#   '专门',
#   '办公室',
#   '电脑',
#   '公司',
#   '内部',
#   '通讯',
#   '软件',
#   '奖金',
#   '单',
#   '扫描',
#   '件',
#   '删除',
#   '理由',
#   '曾经',
#   '信息部',
#   '后台',
#   '看到',
#   '下属',
#   '发',
#   '高额',
#   '奖金',
#   '单',
#   '公开',
#   '内部',
#   '论坛',
#   '公平',
#   '听',
#   '这番',
#   '掩耳盗铃',
#   '操作',
#   '想',
#   '说明',
#   '奖金',
#   '高',
#   '感激',
#   '后来',
#   '转述',
#   '一把手',
#   '年底',
#   '整理',
#   '收入',
#   '发现',
#   '收入',
#   '太高',
#   '骂',
#   '一顿',
#   '以后',
#   '注意',
#   '限',
#   '收入',
#   '在我看来',
#   '明明',
#   '一场',
#   '自导自演',
#   '戏',
#   '\\',
#   'n',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   '后来',
#   '科室',
#   '里',
#   '安排',
#   'A',
#   '项目',
#   '百般刁难',
#   '挑拨离间',
#   '不说',
#   '暗示',
#   '辜负',
#   '培养',
#   '吃里扒外',
#   '倒',
#   '帮',
#   '竞争对手',
#   '几番',
#   '找',
#   '谈话',
#   '施加',
#   '巨大',
#   '心理压力',
#   '之后',
#   '项目',
#   '找',
#   '施压',
#   '推掉',
#   '一次',
#   '群里',
#   '回',
#   'A',
#   '收到',
#   '训话',
#   '好久',
#   '小肚鸡肠',
#   '瞠目结舌',
#   '难受',
#   '直接',
#   '两天',
#   '假',
#   '在家',
#   '躺',
#   '现在',
#   '想起',
#   '曲里拐弯',
#   '理直气壮',
#   '话',
#   '胸闷',
#   '明白',
#   '挑',
#   '软柿子',
#   '捏',
#   '捏',
#   '爆',
#   '柿子',
#   '根本',
#   '不在乎',
#   '\\',
#   'n',
#   ' ',
#   ' ',
#   ' ',
#   '之前',
#   '一直',
#   '用人权',
#   '后来',
#   '发现',
#   '并非如此',
#   '方式',
#   '实际上',
#   '没有',
#   '权力',
#   '下达',
#   '安排',
#   '作出',
#   '承诺',
#   '公司',
#   '制度',
#   '体系',
#   '人情世故',
#   '不大',
#   '熟悉',
#   '真',
#   '镇住',
#   '后来',
#   '出',
#   '问题',
#   '一点',
#   '团队',
#   '内部',
#   '意见',
#   '别乱',
#   '安排',
#   '事情',
#   '知道',
#   '单方面',
#   '发',
#   '淫威',
#   '每次',
#   '碰上',
#   '事',
#   '浑身上下',
#   ...],
#  ['职场',
#   'pua',
#   '五天',
#   '受不了',
#   '大佬',
#   '应对',
#   '现已',
#   '辞职',
#   '心里',
#   '面',
#   '每天',
#   '懊悔',
#   '当时',
#   '太',
#   '怂',
#   '没',
#   '怼',
#   '一句',
#   '话',
#   '[',
#   "'",
#   '笑',
#   '拉',
#   '当时',
#   '招人',
#   '整出',
#   '一副',
#   '三万多',
#   '架势',
#   '考试',
#   '竞争上岗',
#   '公司',
#   '附近',
#   '租好',
#   '房子',
#   '随叫随到',
#   '房子',
#   '租好',
#   '公司',
#   '报道',
#   '第一天',
#   '竞争上岗',
#   '上班',
#   '第一天',
#   '说话',
#   '失望',
#   '每天',
#   '白',
#   '眼看',
#   '办公室',
#   '骂',
#   '原来',
#   '挑来',
#   '挑去',
#   '是因为',
#   '保姆',
#   '\\',
#   'n',
#   '\\',
#   'n',
#   '广西',
#   '数易',
#   '咨询',
#   '有限公司',
#   '李老板',
#   '活',
#   '80',
#   '年代',
#   '觉得',
#   '3000',
#   '买下',
#   '一天',
#   '时间',
#   '一个月',
#   '三万',
#   '买',
#   '不下',
#   '尊严',
#   '底气',
#   '天天',
#   '骂',
#   '员工',
#   '一句',
#   '大病',
#   '没事',
#   '员工',
#   '办公室',
#   '骂',
#   '职场',
#   'pua',
#   '画',
#   '大饼',
#   '吹牛',
#   '逼',
#   '尊重',
#   '当人',
#   '特征',
#   '沾边',
#   's',
#   'laji',
#   '东西',
#   '🐶',
#   ' ',
#   '东西',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '图为',
#   '当时',
#   '竞争上岗',
#   '选上',
#   '妹子',
#   '当时',
#   '第一天',
#   '过去',
#   '坐在',
#   '座位',
#   '活泼',
#   '老板',
#   '孤立',
#   "'",
#   ']',
#   '[',
#   ']'],
#  ['第一份',
#   '工作',
#   '懂',
#   'pua',
#   '[',
#   "'",
#   '记录',
#   '第一份',
#   '工作',
#   '遇到',
#   '雷',
#   '英语',
#   '培训',
#   '机构',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '1',
#   '.',
#   '几乎',
#   '天天',
#   '加班',
#   '没见',
#   '加班费',
#   '基本',
#   '每天',
#   '10',
#   '左右',
#   'hr',
#   '长沙',
#   '基本',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '2',
#   '.',
#   '公司',
#   '没有',
#   '打卡机',
#   '早上',
#   'hr',
#   '门口',
#   '迟到',
#   '罚款',
#   '50',
#   '从没',
#   '下班',
#   '事',
#   '第一份',
#   '工作',
#   '懂',
#   '胆子',
#   '主管',
#   '不说',
#   '不敢',
#   '下班',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '3',
#   '.',
#   '部门经理',
#   '业务',
#   '能力差',
#   '提到',
#   '下班',
#   '事情',
#   ':',
#   '知道',
#   '下班',
#   '回去',
#   '早',
#   '干什么',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '4.8',
#   '点半',
#   '上班',
#   '每周三',
#   '经理',
#   '要开',
#   '例会',
#   '线上',
#   '在家',
#   '开',
#   '集体',
#   '公司',
#   '开',
#   '早上',
#   '7',
#   '点开',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '提出',
#   '是非',
#   '工作',
#   '时间',
#   '会议',
#   '参加',
#   '自愿',
#   '参与',
#   '实在',
#   '早起',
#   '后来',
#   '参加',
#   '每次',
#   '快',
#   '7',
#   '主管',
#   '打电话',
#   '继续',
#   '睡',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '5',
#   '.',
#   '累',
#   '活儿',
#   '没',
#   '愿意',
#   '开会',
#   '一个个',
#   '点名',
#   '问',
#   '愿不愿意',
#   '团队',
#   '贡献',
#   '已经',
#   '清醒',
#   '直接',
#   '愿意',
#   '预感',
#   '愿意',
#   '活儿',
#   '说话',
#   '之前',
#   '愿意',
#   '说话',
#   '之后',
#   '愿意',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '6',
#   '.',
#   '每周',
#   '一本',
#   '指定',
#   '书',
#   '周一',
#   '全',
#   '公司',
#   '开会',
#   '分组讨论',
#   '读书',
#   '心得',
#   '每组',
#   '选',
#   '代表',
#   '分享',
#   '书',
#   '买',
#   '要求',
#   '一定',
#   '买',
#   '读书',
#   'app',
#   '会员',
#   '每次',
#   '开会',
#   '问',
#   '有没有',
#   '买',
#   '没有',
#   '买',
#   '举手',
#   '一个个',
#   '问',
#   '不买',
#   '一直',
#   '没买',
#   '穷',
#   '没敢',
#   '举手',
#   '🙋',
#   '🏻',
#   '\\',
#   'u200d',
#   '♂',
#   '️',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '后续',
#   '已经',
#   '离职',
#   '3',
#   '记忆犹新',
#   '当时',
#   '走',
#   '是因为',
#   '看不惯',
#   '主管',
#   '挺',
#   '欺软怕硬',
#   '后来',
#   '比较',
#   '硬气',
#   '没敢',
#   '有个',
#   '妹子',
#   '脾气',
#   '软',
#   '端午',
#   '想',
#   '一天',
#   '假',
#   '好合',
#   '老公',
#   '放假',
#   '时间',
#   '一起',
#   '回老家',
#   '主管',
#   '死活',
#   '同意',
#   '请假',
#   '只能',
#   '调休',
#   '端午',
#   '假',
#   '最后',
#   '一天',
#   '全',
#   '公司',
#   '人来',
#   '上班',
#   '公司',
#   '发',
#   '数据',
#   '刚好',
#   '看到',
#   '没什么',
#   '事情',
#   '根本',
#   '没有',
#   '意义',
#   '没',
#   '意识',
#   '职场',
#   'pua',
#   '事情',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '现在',
#   '懂得',
#   '保护',
#   '下班',
#   '打招呼',
#   '走',
#   '打卡',
#   '走',
#   '不该',
#   '讲清楚',
#   '同事',
#   '人间',
#   '清醒',
#   '哈哈哈',
#   '知道',
#   '以前',
#   '傻',
#   '工作',
#   '其实',
#   '斗志',
#   '满满的',
#   '后来',
#   '工作',
#   '没',
#   '那份心',
#   '真的',
#   '浪费',
#   "'",
#   ']',
#   '[',
#   ']'],
#  ['职场',
#   'pua',
#   '[',
#   "'",
#   ' ',
#   '店长',
#   '不常',
#   '店里',
#   '上班',
#   '平时',
#   '几乎',
#   '啥事',
#   '操心',
#   '回来',
#   '挑事',
#   "'",
#   ',',
#   ' ',
#   "'",
#   ' ',
#   ' ',
#   ' ',
#   '明明',
#   '主管',
#   '事情',
#   '非拉着',
#   '一起',
#   '批评',
#   '美其名曰',
#   '怕',
#   '单独',
#   '谈话',
#   '当事人',
#   '玻璃心',
#   '受不了',
#   '用人',
#   '水平',
#   '低劣',
#   '尤其',
#   '谈话',
#   '过程',
#   '中看',
#   '眼神',
#   '受不了',
#   '犯了错',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '捋',
#   '不清',
#   '工作思路',
#   '挑出',
#   '可怜',
#   '刚入',
#   '职',
#   '主管',
#   '听',
#   '云里雾里',
#   '她俩',
#   '尴尬',
#   "'",
#   ',',
#   ' ',
#   "'",
#   ' ',
#   '平时',
#   '讲话',
#   '拎不清',
#   '重点',
#   '说话',
#   '漫无目的',
#   '超级',
#   '啰嗦',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '反感',
#   '不能',
#   '知行合一',
#   '行为',
#   '世范',
#   '参与',
#   '工作',
#   '里面',
#   '不会',
#   '分工',
#   '挑毛病',
#   '提提',
#   '建议',
#   '无辜',
#   '委屈',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '关键',
#   '面对',
#   '重视',
#   '真是',
#   '语',
#   '共事',
#   '几个',
#   '真',
#   '没',
#   '亲眼',
#   '见证',
#   '牛',
#   '逼',
#   '之处',
#   '工作',
#   '技能',
#   '跳舞',
#   '不会',
#   '活动',
#   '不带',
#   '就会',
#   '花个',
#   '时间',
#   '理个',
#   '账',
#   '个体',
#   '工商户',
#   '做账',
#   '没',
#   '复杂',
#   '业务',
#   '一收',
#   '一支',
#   '两条线',
#   '查查',
#   '原始凭证',
#   '记账',
#   '凭证',
#   '做个',
#   '核对',
#   '正常',
#   "'",
#   ']',
#   '[',
#   "'",
#   '遇到',
#   '啰嗦',
#   '真的',
#   '无奈',
#   '可能',
#   '消化',
#   '废话',
#   '讲话',
#   '简明扼要',
#   '即可',
#   '来讲',
#   '够',
#   '难',
#   "'",
#   ']'],
#  ['教培裸辞',
#   '民办小学',
#   'or',
#   '公办',
#   '合同制',
#   '老师',
#   '[',
#   "'",
#   '求助',
#   '👊',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '目前',
#   '教培裸辞',
#   '面试',
#   '一家',
#   '民办',
#   '9',
#   '年制',
#   '学校',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '坐标',
#   '一线',
#   '城市',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '安排',
#   '教',
#   '6',
#   '年级',
#   '后升',
#   '初中',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '基本工资',
#   '5k',
#   '➕',
#   '几百',
#   '课时费',
#   '班主任',
#   '补贴',
#   '2k',
#   '.',
#   '包吃',
#   '住',
#   '象征性',
#   '付费',
#   '真的',
#   '略低',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '值不值得',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '选择',
#   '等待',
#   '考',
#   '公办',
#   '合同制',
#   '大学',
#   '专业',
#   '对口',
#   '能考',
#   '岗位',
#   "'",
#   ']',
#   '[',
#   "'",
#   '貌似',
#   '发错',
#   '组了',
#   '😂',
#   '😂',
#   "'",
#   ']'],
#  ['帮忙',
#   '看看',
#   '是不是',
#   'pua',
#   '[',
#   "'",
#   '这是',
#   '最近',
#   '之前',
#   '一次',
#   '开会',
#   '当众',
#   '贬低',
#   '现在',
#   '能力',
#   '学校',
#   '不会',
#   '大骂',
#   '原来',
#   '跳板',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '图片',
#   '一部分',
#   'btw',
#   '老师',
#   '月入',
#   '晚上',
#   '周末',
#   '上课',
#   '已经',
#   '属实',
#   '老师',
#   '暑假',
#   '多课',
#   '早排',
#   '晚',
#   '可能',
#   '...',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '工作',
#   '谴责',
#   '知道',
#   '次',
#   '加上',
#   '代沟',
#   '经常',
#   '三两句',
#   '没对',
#   '发脾气',
#   '🙄',
#   "'",
#   ',',
#   ' ',
#   "'",
#   "'",
#   ',',
#   ' ',
#   "'",
#   '大概',
#   '情况',
#   '本来',
#   '当初',
#   '急',
#   '老板',
#   '过来',
#   '帮忙',
#   '试用期',
#   '三个',
#   '现在',
#   '三个',
#   '不见得',
#   '提',
#   '转正',
#   '每个',
#   '底薪',
#   '2k',
#   '加一点',
#   '绩效',
#   '没有',
#   '社保',
#   '没有',
#   '合同',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '承认',
#   '贡献',
#   '图得',
#   '落脚点',
#   '锻炼',
#   '地方',
#   '来到',
#   '之后',
#   '工作',
#   '很闲',
#   '招',
#   '不到',
#   '生',
#   '懒得',
#   '经常',
#   '要求',
#   '一堆',
#   '不好',
#   '不好',
#   '动不动',
#   '画饼',
#   '问题',
#   '我来',
#   '之后',
#   '现有',
#   '物质',
#   '资源',
#   '资源',
#   '没',
#   '提供',
#   '搞',
#   '培训',
#   '老师',
#   '成长',
#   '良性',
#   '化发展',
#   '限制',
#   '现有',
#   '物质',
#   '资源',
#   '...',
#   '工作',
#   '时间',
#   '塞',
#   '私事',
#   '过来',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '目前',
#   '得不到',
#   '锻炼',
#   '成长',
#   '上边',
#   '一直',
#   '这种',
#   '要求',
#   'pua',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '感觉',
#   '说白了',
#   '应届生',
#   '刚出',
#   '社会',
#   '知道',
#   '2k',
#   '块',
#   '买个',
#   '清洁工',
#   '+',
#   '前台',
#   '+',
#   '助教',
#   '图个',
#   '清闲',
#   '有空',
#   '备考',
#   '一直',
#   '留在',
#   '打算',
#   '长远',
#   '育苗',
#   '傻傻',
#   '听',
#   '绩效',
#   '里面',
#   '事情',
#   '现在',
#   '学生',
#   '老师',
#   '布置',
#   '说考',
#   '满分',
#   '最棒',
#   '生活',
#   '事情',
#   '那点',
#   '绩效',
#   '重要',
#   "'",
#   ']',
#   '[',
#   ']'],
#  ['老板',
#   '职场',
#   'pua',
#   '现在',
#   '阴影',
#   '[',
#   "'",
#   '刚入',
#   '职',
#   '这家',
#   '公司',
#   '不到',
#   '两个',
#   '创业',
#   '公司',
#   '包括',
#   '老板',
#   '公司员工',
#   '一共',
#   '6',
#   '个人',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '刚',
#   '过去',
#   '信心',
#   '满满',
#   '老板',
#   '期待',
#   '想',
#   '好好',
#   '做出',
#   '成绩',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '声明',
#   '一下',
#   '之前',
#   '公司',
#   '职位',
#   '设计',
#   '小组',
#   '负责人',
#   '后面',
#   '来到',
#   '这家',
#   '公司',
#   '设计',
#   '项目',
#   '一位',
#   '老',
#   '员工',
#   '对接',
#   '主导',
#   '进行',
#   '设计',
#   '擅长',
#   '风格',
#   '方法',
#   '有点',
#   '出力',
#   '楼主',
#   '仍然',
#   '想',
#   '解决办法',
#   '一直',
#   '想',
#   '认认真真',
#   '做出',
#   '成绩',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '后面',
#   '老板',
#   '出',
#   '策划案',
#   '新',
#   '项目',
#   '老板',
#   '发',
#   '进度',
#   '最终',
#   '汇报',
#   '老板',
#   '想要',
#   '咨询',
#   '改进',
#   '老板',
#   '没有',
#   '提出',
#   '建设性',
#   '意见',
#   '之后',
#   '日子',
#   '里',
#   '几乎',
#   '方案',
#   '砍掉',
#   '深深',
#   '陷入',
#   '自我',
#   '怀疑',
#   '同样',
#   '咨询',
#   '同行',
#   '朋友',
#   '同行',
#   '朋友',
#   '做法',
#   '认可',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '后面',
#   '老板',
#   '一直',
#   '不好',
#   '效率',
#   '低下',
#   '没有',
#   '自驱力',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '试用期',
#   '结束',
#   '前',
#   '星期',
#   '老板',
#   '聊',
#   '转正',
#   '事情',
#   '老板',
#   '没有',
#   '达到',
#   '预想',
#   '期盼',
#   '值',
#   '举',
#   '例子',
#   '否定',
#   '薪资',
#   '算是',
#   '中上',
#   '薪资',
#   '招',
#   '更好',
#   '降薪',
#   '转正',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '楼主',
#   '同意',
#   '第二天',
#   '早上',
#   '提出',
#   '离职',
#   '老板',
#   '想',
#   '挽留',
#   '同意',
#   '降薪',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '辞职',
#   '脑海',
#   '里',
#   '一直',
#   '想着',
#   '不好',
#   '不好',
#   '现在',
#   '有点',
#   '不敢',
#   '面试',
#   '找',
#   '工作',
#   '😪',
#   "'",
#   ']',
#   '[',
#   "'",
#   '单纯',
#   '压价',
#   ' ',
#   '借口',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '想',
#   '辞退',
#   '不说',
#   '标准',
#   '符合',
#   '想法',
#   '知道',
#   '想要',
#   '只会',
#   'p',
#   '不行',
#   '彩色',
#   '黑',
#   '同行',
#   '没',
#   '问题',
#   '赶紧',
#   '跑',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '回来',
#   '回复',
#   '离职',
#   '感觉',
#   '阴影',
#   '几天',
#   '面试',
#   '没有',
#   '自信',
#   '😔',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '楼主',
#   '同样',
#   '设计',
#   '行业',
#   ' ',
#   '一毛',
#   '经历',
#   ' ',
#   '一再',
#   '不再',
#   '无理',
#   '谩骂',
#   '打压',
#   ' ',
#   '直接',
#   '走',
#   ' ',
#   '昨天',
#   ' ',
#   '前辈',
#   '愿意',
#   '一辈子',
#   '领悟',
#   '东西',
#   ' ',
#   '不在乎',
#   '两三年',
#   ' ',
#   '在乎',
#   '东西',
#   '根本',
#   '看不到',
#   ' ',
#   '再见',
#   '呐',
#   ' ',
#   '楼主',
#   '加油',
#   ' ',
#   '未来',
#   '无限量',
#   ' ',
#   "'",
#   ']'],
#  ['老',
#   '职场',
#   '新',
#   'PUA',
#   '[',
#   "'",
#   '这家',
#   '企业',
#   '8',
#   '转到',
#   '新',
#   '部门',
#   '2',
#   '新',
#   '部门',
#   '领导',
#   '真',
#   '折磨',
#   '死',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '1',
#   '.',
#   ' ',
#   '任务分配',
#   '下来',
#   '注意',
#   '培养',
#   '没有',
#   '问',
#   '想',
#   '摸索',
#   '告诉',
#   '成长',
#   '价值',
#   '导致',
#   '不敢',
#   '问',
#   '方式',
#   '方法',
#   '问多',
#   '依赖',
#   '设',
#   '限制',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '2',
#   '.',
#   '任务',
#   '完成',
#   '找',
#   '确认',
#   '核对',
#   '找出',
#   '一大堆',
#   '问题',
#   '思考',
#   '盲点',
#   '设计',
#   '盲点',
#   '想法',
#   '不足',
#   '部分',
#   '导致',
#   '一次',
#   '一次',
#   '能力',
#   '产生',
#   '怀疑',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '3',
#   '.',
#   '沟通',
#   '对接',
#   '事情',
#   '过程',
#   '总是',
#   '无效',
#   '沟通',
#   '找错',
#   '否定',
#   '思考',
#   '批判',
#   '思考',
#   '嘲讽',
#   '理性',
#   '沟通',
#   '感性',
#   '方面',
#   '不会',
#   '过多',
#   '感性',
#   '导致',
#   '非常',
#   '讨厌',
#   '沟通',
#   '对接',
#   '事情',
#   "'",
#   ',',
#   ' ',
#   "'",
#   "'",
#   ',',
#   ' ',
#   "'",
#   '反抗',
#   '过程',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '这周',
#   '找',
#   '领导',
#   '领导',
#   '聊',
#   '一次',
#   '讲',
#   '部门',
#   '感受',
#   '看法',
#   '提出',
#   '转岗',
#   '项目',
#   '现场',
#   '岗位职责',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '领导',
#   '反馈',
#   '新',
#   '领导',
#   '方式',
#   '方法',
#   '有待',
#   '提高',
#   '希望',
#   '杆子',
#   '打死',
#   '跑掉',
#   '希望',
#   '机会',
#   '调整',
#   '项目',
#   '现场',
#   '岗位职责',
#   '不变',
#   '行政',
#   '规划',
#   '属于',
#   '新',
#   '领导',
#   '管辖',
#   '唯一',
#   '好处',
#   '一起',
#   '办公',
#   '办公',
#   '内容',
#   '不受',
#   '管辖',
#   "'",
#   ',',
#   ' ',
#   "'",
#   "'",
#   ',',
#   ' ',
#   "'",
#   '反抗',
#   '影响',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '接受',
#   '领导',
#   '调整',
#   '两天',
#   '项目',
#   '现场',
#   '工作',
#   '遇到',
#   '不会',
#   '事情',
#   '想不到',
#   '办法',
#   '事情',
#   '想到',
#   'sha',
#   ' ',
#   ' ',
#   'b',
#   '领导',
#   '评价',
#   '过多',
#   '依赖',
#   '方法',
#   '没有',
#   '主动',
#   '意识',
#   "'",
#   ',',
#   ' ',
#   "'",
#   "'",
#   ',',
#   ' ',
#   "'",
#   "'",
#   ']',
#   '[',
#   "'",
#   '更新',
#   '12',
#   '月份',
#   '离职',
#   '休养',
#   '现在',
#   '新',
#   '工作',
#   '2',
#   '…',
#   '…',
#   '\\',
#   'n',
#   '正在',
#   '自愈',
#   '没有',
#   '完全',
#   '偶尔',
#   '发作',
#   '自我',
#   '怀疑',
#   '攻击性',
#   '极强',
#   '反应',
#   '…',
#   '\\',
#   'n',
#   '希望',
#   '后面',
#   '回到',
#   '以前',
#   '还会',
#   '更新',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '更新',
#   '12',
#   '月份',
#   '离职',
#   '休养',
#   '现在',
#   '新',
#   '工作',
#   '2',
#   '…',
#   '…',
#   '\\',
#   'n',
#   '正在',
#   '自愈',
#   '没有',
#   '完全',
#   '偶尔',
#   '发作',
#   '自我',
#   '怀疑',
#   '攻击性',
#   '极强',
#   '反应',
#   '…',
#   '\\',
#   'n',
#   '希望',
#   '后面',
#   '回到',
#   '以前',
#   '还会',
#   '更新',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '发',
#   '贴',
#   ' ',
#   '一模一样',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '深有同感',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '确实',
#   'pua',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '段时间',
#   '睡觉',
#   '前',
#   '满脑子',
#   '想',
#   '批评',
#   '否定',
#   '真的',
#   '不会',
#   '需求',
#   '…',
#   '…',
#   "'",
#   ']'],
#  ['感觉',
#   'pua',
#   '[',
#   "'",
#   '今天',
#   '排班',
#   ' ',
#   ' ',
#   '班',
#   '走',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '拍',
#   '中间',
#   '休假',
#   '放在',
#   '1',
#   '-',
#   '5',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '放',
#   '放',
#   '那天',
#   '否',
#   ' ',
#   ' ',
#   '刚刚',
#   '否',
#   '记得',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '问',
#   '班次',
#   '问题',
#   '有没有',
#   '普通',
#   '同事',
#   "'",
#   ',',
#   ' ',
#   "'",
#   ':',
#   '两千多',
#   '(',
#   '夸张',
#   '普通',
#   '三千多',
#   ')',
#   '五千多',
#   "'",
#   ',',
#   ' ',
#   "'",
#   ':',
#   '没有',
#   '四千多',
#   ' ',
#   '(',
#   '普通',
#   '同事',
#   '基本上',
#   '加班',
#   '补',
#   '休假',
#   '一个月',
#   '下来',
#   '半个',
#   '休',
#   ')',
#   "'",
#   ',',
#   ' ',
#   "'",
#   ':',
#   '学到',
#   "'",
#   ',',
#   ' ',
#   "'",
#   ':',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '工资',
#   '说事',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '真的',
#   '很无语',
#   '工资',
#   '高',
#   ' ',
#   ' ',
#   '一批',
#   '计划',
#   '招进来',
#   '1',
#   '.',
#   '正好',
#   '计划',
#   '2',
#   '.',
#   '相对',
#   '工资',
#   '高',
#   '双休',
#   '无偿',
#   '加班',
#   '3',
#   '.',
#   '普通',
#   '同事',
#   '休假',
#   "'",
#   ',',
#   ' ',
#   "'",
#   '现在',
#   '想',
#   '起来',
#   '后悔',
#   '没有',
#   '找到',
#   '怼',
#   '回去',
#   '生气',
#   '生气',
#   '💢',
#   '💢',
#   '💢',
#   '💢',
#   "'",
#   ']',
#   '[',
#   ']'],
#  ['这种',
#   '公司',
#   '正常',
#   '[',
#   "'",
#   '\\',
#   'n',
#   '小白',
#   '意见',
#   '\\',
#   'n',
#   '\\',
#   'n',
#   '18',
#   '开学',
#   '大二',
#   '第一次',
#   '暑假',
#   '工',
#   '辅导',
#   '机构',
#   '助教',
#   '机构',
#   '规模',
#   '不大不小',
#   '老板',
#   '任务',
#   '每天',
#   '超额',
#   '导致',
#   '每天',
#   '不能',
#   '按时',
#   '下班',
#   '保证',
#   '注意力',
#   '集中',
#   '效率高',
#   '完成',
#   '每天',
#   '安排',
#   '干',
#   '杂事',
#   '根本无法',
#   '规定',
#   '时间',
#   '完成',
#   '老板',
#   '支持',
#   '加班',
#   '加班',
#   '骂',
#   '管理人员',
#   '很多',
#   '小事',
#   '管理人员',
#   '意见',
#   '一致',
#   '这种',
#   '小白',
#   '根本',
#   '知道',
#   '咋办',
#   '\\',
#   'n',
#   '工作',
#   '环境',
#   '太',
#   '压抑',
#   '每天',
#   '耳边',
#   '充斥',
#   '各种各样',
#   '批评',
#   '声',
#   '不怎么',
#   '主课',
#   '老师',
#   '沟通',
#   '导致',
#   '工作',
#   '无法',
#   '顺利',
#   '完美',
#   '完成',
#   '批改',
#   '作文',
#   '特别',
#   '每天',
#   '催促',
#   '老板',
#   '认为',
#   '工作',
#   '简单',
#   '兼职',
#   '老师',
#   '并不认为',
#   '简单',
#   '基本上',
#   '催促',
#   '\\',
#   'n',
#   '工资',
#   '十八',
#   '线',
#   '城市',
#   '一天',
#   '八十',
#   '\\',
#   'n',
#   '干够',
#   '十五天',
#   '现在',
#   '走',
#   '工资',
#   '会少',
#   '一半',
#   '继续',
#   '留在',
#   '地方',
#   '\\',
#   'n',
#   '地方',
#   '真的',
#   '压抑',
#   "'",
#   ']',
#   '[',
#   "'",
#   '正常',
#   '相当',
#   '正常',
#   "'",
#   ']']]

# %%
model = Word2Vec(douban_all_text_token, workers=4, vector_size=300, min_count=10, window=10, sample=1e-3)

# %%
len(model.wv) #vocab size
# Out:
# 85

# %%
# Plot the tSNE!
tsne_plot(model)
# Out:
# /Users/randgrant/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /Users/randgrant/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(

# %% [markdown]
# ## t-SNE within Chinese Word Embeddings

# %%
wv_model = []

for post_token in douban_all_text_token:
    for word in post_token:
        if word not in wv_model:
            wv_model.append(word)

# %%
len(wv_model)
# Out:
# 2341

# %%
# ?wv.index_to_key
# Out:
# Type:        list
# String form: ['，', '的', '。', '@', '！', '了', '、', '：', '】', '是', '和', '有', '在', '一', '？', '“', '不', '个', '我', ' <...> avel#', 'aEuDIJ', '运是要', '0564', '毛求大', '鱼有礼', '#Mission', 'wu-gen-li', '@Dam', 'chwlibj', '黄小莫']
# Length:      195202
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
ar=[1,2,3]

try:
    t=ar[3]
# Out:
#   File "/var/folders/r1/zv_cgpdj61b8c60j_yk8lx900000gn/T/ipykernel_3649/869368423.py", line 3
#     try: t=ar[3]
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
# Modified for existing Chinese Word Embeddings

# From https://www.kaggle.com/jeffd23/visualizing-word-vectors-with-t-sne
def tsne_plot_modified(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in wv_model:
        if word in wv.index_to_key:
            tokens.append(wv[word])
            labels.append(word)
    
    tsne_model = TSNE(perplexity=40, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16)) 
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom',
                     fontproperties=prop,
                     size=14)
    plt.show()

# %%
tsne_plot_modified(wv_model)
# Out:
# /Users/randgrant/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /Users/randgrant/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
