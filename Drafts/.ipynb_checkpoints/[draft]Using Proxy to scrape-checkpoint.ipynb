# %%
# Caculation
import numpy as np
import re
from numpy import random

# Scraping
from bs4 import BeautifulSoup
import requests
import time
import urllib
from urllib.request import Request, urlopen, ProxyHandler, build_opener, install_opener, HTTPHandler
from urllib.error import HTTPError, URLError
from urllib.parse import quote

# Show Results
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Setting User Agents

USER_AGENTS = [
    {'User-Agent': 'Mozilla/5.0 (Linux; Android 7.1.1; SM-A530F Build/NMF26X; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/64.0.3282.137 Mobile Safari/537.36 YandexSearch/7.21'},
    {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.12 Safari/535.11'},
    {'User-Agent': 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; Trident/6.0)'},
    {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:73.0) Gecko/20100101 Firefox/73.0'},
    {'User-Agent': 'Mozilla/5.0 (Linux; Android 10; P40) AppleWebKit/537.36 (KHTML, like Gecko) SamsungBrowser/15.0 Chrome/90.0.4430.210 Mobile Safari/537.36'},
    {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:23.0) Gecko/20100101 Firefox/23.0'},
    {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'},
    {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36'},
    {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:30.0) Gecko/20100101 Firefox/30.0'},
    {'User-Agent': 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_8) AppleWebKit/5331 (KHTML, like Gecko) Chrome/37.0.840.0 Mobile Safari/5331'},
    {'User-Agent': 'Mozilla/5.0 (Linux; Android 9; Redmi Note 7) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4603.0 Mobile Safari/537.36'},
    {'User-Agent': 'Mozilla/5.0 (compatible; Konqueror/3.5; Linux) KHTML/3.5.5 (like Gecko) (Kubuntu)'},
    {'User-Agent': 'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8.0.12) Gecko/20070731 Ubuntu/dapper-security Firefox/1.5.0.12'},
    {'User-Agent': 'Mozilla/5.0 (X11; Linux i686) AppleWebKit/535.7 (KHTML, like Gecko) Ubuntu/11.04 Chromium/16.0.912.77 Chrome/16.0.912.77 Safari/535.7'},
    {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:10.0) Gecko/20100101 Firefox/10.0'},
    {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.36'}]

# %%
# Scraping Free Proxy Site

url = "https://free-proxy-list.net/anonymous-proxy.html"
page = requests.get(url)
soup = BeautifulSoup(page.text,"html.parser")
proxy_df = soup.find("tbody")
proxy_single = proxy_df.find_all("tr")

# %%
#Setting Proxies

proxy_list = []
for index in range(len(proxy_single)):
    if proxy_single[index].find_all("td")[6].text == "yes":
        address = str(proxy_single[index].find_all("td")[0].text)
        port = str(proxy_single[index].find_all("td")[1].text)
        #proxy_list.append(str("https://" + address + ":" + port))
        proxy_list.append(str(address + ":" + port))
PROXY_IPS = []
for index in range(len(proxy_list)):
    PROXY_IPS.append({"http": proxy_list[index]})

# %%
print(proxy_single[3].find_all("td")[0].text)
# Out:
# 206.189.30.235

# %%
PROXY_IPS
# Out:
# [{'http': '46.175.70.69:44239'},
#  {'http': '95.53.246.137:3128'},
#  {'http': '195.53.49.11:3128'},
#  {'http': '202.57.35.74:38629'},
#  {'http': '85.172.39.174:47326'},
#  {'http': '177.87.168.105:53281'},
#  {'http': '187.44.167.78:60786'},
#  {'http': '103.155.196.114:8181'},
#  {'http': '103.101.3.19:8080'},
#  {'http': '185.175.119.113:47174'},
#  {'http': '47.74.226.8:5001'},
#  {'http': '103.56.207.234:8080'},
#  {'http': '207.244.227.169:443'},
#  {'http': '185.191.164.114:26691'},
#  {'http': '81.24.90.43:41258'},
#  {'http': '51.159.24.172:3167'},
#  {'http': '83.151.2.50:3128'},
#  {'http': '78.47.223.55:5566'},
#  {'http': '85.195.104.71:80'},
#  {'http': '41.234.66.33:3128'},
#  {'http': '154.236.177.100:1981'},
#  {'http': '45.128.220.194:59394'},
#  {'http': '45.128.220.34:59394'},
#  {'http': '47.242.69.151:59394'},
#  {'http': '45.128.220.109:59394'},
#  {'http': '43.129.233.87:59394'},
#  {'http': '164.68.123.119:9300'},
#  {'http': '129.226.113.45:59394'},
#  {'http': '66.70.178.214:9300'},
#  {'http': '103.133.24.97:8181'},
#  {'http': '37.59.186.237:3128'},
#  {'http': '172.107.96.30:443'},
#  {'http': '163.172.35.121:8088'}]

# %%
#TEST

url = 'http://ip4only.me'


headers = random.choice(USER_AGENTS)
proxies = random.choice(PROXY_IPS)
print("Connect to: " + str(proxies))
print("Header:" + str(headers))
req = requests.get(url, proxies=proxies, headers = headers)
soup = BeautifulSoup(req.text,"html.parser")
# Out:
# Connect to: {'http': '187.44.167.78:60786'}
# Header:{'User-Agent': 'Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6_8) AppleWebKit/5331 (KHTML, like Gecko) Chrome/37.0.840.0 Mobile Safari/5331'}

# %%
soup.text
# Out:
# '\n\nWhat is my IP Address?\n\nThis page shows your IPv4 or IPv6 address\n\nYou are connecting with an IPv4 Address of:\n187.44.167.78\nIPv4 only Test\nNormal Test\nIPv6 only Test\n\xa0If the IPv6 only test shows "Server not found" or similar error or search page then you do not have working IPv6 connectivity.\n"Normal Test" shows which protocol your browser preferrs when you have both IPv4 and IPv6 connectivity.\n\xa0You can access this page with any of these easy to remember url\'s:\n\xa0ip4.me - IPv4 only test\nip6.me - IPv6 test with IPv4 fallback\nip6only.me - IPv6 only test\nwhatismyv6.com - IPv6 test with IPv4 fallback\n\xa0For automated queries use /api/ on any of the urls for a simple plain text csv result that will not be affected by future html changes on the main page.\nRecommended API urls(Don\'t forget the trailing slash to avoid unnessary 301 redirects):\n\xa0ip4only.me/api/ - IPv4 only test\nip6.me/api/ - IPv6 test with IPv4 fallback\nip6only.me/api/ - IPv6 only test\n\xa0Some day far in the future ip4.me may have a AAAA record so it is not recommended for "IPv4 only" automated queries.  Use ip4only.me instead.\n\n\n©2020 Dulles Internet Exchange, LLC.  All rights reserved.\n\n\n\n'

# %% [markdown]
# ### "反洗脑，反PUA" Dataset Scraping

# %%
#Request certain group discussion page

#First make the url
group_discussion_url = 'http://www.douban.com/group/nopua/discussion?start='

#For every page
group_disscusion_number = 0

#Make a Header & Proxie
headers = random.choice(USER_AGENTS)
proxies = random.choice(PROXY_IPS)
print("Connect to: " + str(proxies))
print("Header:" + str(headers))
print("------")


#Request & transfer the page (referenced from Github)
group_discussion_url = group_discussion_url + str(group_disscusion_number)
group_dis_req = requests.get(group_discussion_url, proxies=proxies, headers=headers)
group_dis_page_text = BeautifulSoup(group_dis_req.text,"html.parser")
# Out:
# Connect to: {'http': '78.47.223.55:5566'}
# Header:{'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:23.0) Gecko/20100101 Firefox/23.0'}
# ------

# %%
#Scrape certain group discussion list

#BS4-filtering & Documentation
list = group_dis_page_text.find_all("tr")

#Store every post Title & Link into a dictionary
grp_dis_list = {}
for i in list:
    if i["class"] == []:
        title = str(i.a["title"])
        link = i.a["href"]
        grp_dis_list[title]=link

# %%
grp_dis_list
# Out:
# {'PUA并不是控制狂，而是有预谋的犯罪。': 'https://www.douban.com/group/topic/190942366/',
#  '虽然我是男的，但是我希望帮到你们': 'https://www.douban.com/group/topic/241541659/',
#  '求大家劝我不要受这个朋友思想控制': 'https://www.douban.com/group/topic/202681033/',
#  '不付出感情就不会受伤吗': 'https://www.douban.com/group/topic/231909770/',
#  '一次被PUA的经历，引以为戒': 'https://www.douban.com/group/topic/172205325/',
#  '一些反思about narcissist': 'https://www.douban.com/group/topic/167041582/',
#  '好像遇到PUA，中度抑郁': 'https://www.douban.com/group/topic/167147725/',
#  '请教': 'https://www.douban.com/group/topic/226407892/',
#  '是不是也有女生的pua组织的？': 'https://www.douban.com/group/topic/225502319/',
#  '年龄绝对不是问题！': 'https://www.douban.com/group/topic/224676359/',
#  '我的职场反PUA日记（二）': 'https://www.douban.com/group/topic/223398486/',
#  '欢迎对PUA情感控制纪录片的朋友们来交流': 'https://www.douban.com/group/topic/223307288/',
#  '指出父母婚姻中的pua，但是被pua的人意识不到🙂': 'https://www.douban.com/group/topic/223180758/',
#  '我的职场反PUA日记（一）': 'https://www.douban.com/group/topic/223139673/',
#  '我好像被好朋友pua了': 'https://www.douban.com/group/topic/220987362/',
#  '学PUA的经历，惊醒下有帮助的人，不定时更新': 'https://www.douban.com/group/topic/204577497/',
#  '不知道我算不算被pua': 'https://www.douban.com/group/topic/193475129/',
#  '我可能被职场PUA了，想确定领导是性格如此还是办公室同事都被PUA': 'https://www.douban.com/group/topic/207566534/',
#  '公然贩卖pua!': 'https://www.douban.com/group/topic/175018657/',
#  '我的论文指导老师，我觉得她有潜意识pua倾向': 'https://www.douban.com/group/topic/204847025/',
#  '求帮分析！怀疑我的朋友在被PUA？': 'https://www.douban.com/group/topic/194833910/',
#  '看到<反PUA笔记整理>作的批注': 'https://www.douban.com/group/topic/203212615/',
#  '很多女大学生被PUA': 'https://www.douban.com/group/topic/191707928/',
#  '我感觉自己被“朋友”PUA了': 'https://www.douban.com/group/topic/186529007/',
#  '见到无数女人败在pua之下': 'https://www.douban.com/group/topic/184636147/',
#  '我好难受好痛苦': 'https://www.douban.com/group/topic/184626029/',
#  '何书桓对依萍说的话': 'https://www.douban.com/group/topic/183943349/',
#  'toxic love &true love': 'https://www.douban.com/group/topic/181184988/',
#  '。': 'https://www.douban.com/group/topic/178745125/',
#  '这几天就很难受……意识到自己其实受伤了': 'https://www.douban.com/group/topic/178568875/'}

# %%
# initialize the dataframe
post_df = pd.DataFrame(columns = ["title","link","main text","reply text"])

# go through every post
for i in grp_dis_list:
    
    print("Scraping post: ", i )
    
    #Request & Get the html
    grp_dis_list[i] #get the url
    headers = random.choice(USER_AGENTS) #make a fake user
    proxies = random.choice(PROXY_IPS)
    req = requests.get(grp_dis_list[i], proxies=proxies, headers=headers)
    soup = BeautifulSoup(req.text,"html.parser")
    print("Connect to: " + str(proxies))
    print("Header:" + str(headers))
    print("------")
    
    # Post Title / Link
    post = [[]]
    post[0].append(i)
    post[0].append(grp_dis_list[i])
    
    # Post Main Text
    # get main post
    post_main = soup.find("div", class_="rich-content topic-richtext").find_all("p")
    # transfer main post object into a list of strings
    post_main_text = []
    for main in range(len(post_main)):
        post_main_text.append(post_main[main].text)
    
    # Post Reply Text
    #transfer reply post object into a list of strings
    post_reply = soup.find_all(class_="reply-content")
    post_reply_text = []
    for reply in range(len(post_reply)):
        post_reply_text.append(post_reply[reply].text)
    
    # Make the Dataset
    # add single post to data frame
    post[0].append(post_main_text)
    post[0].append(post_reply_text)
    post_df = post_df.append(pd.DataFrame(post, columns = ["title","link","main text","reply text"]))
    
    sleep_time = random.randint(10,20)
    print("Now sleeping for " + str(sleep_time) + "s...")
    time.sleep(sleep_time) # modified from Github Code
# Out:
# Scraping post:  PUA并不是控制狂，而是有预谋的犯罪。
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     695             if is_new_proxy_conn and http_tunnel_required:
# --> 696                 self._prepare_proxy(conn)
#     697
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     963
# --> 964         conn.connect()
#     965
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     370             # self._tunnel_host below.
# --> 371             self._tunnel()
#     372             # Mark this connection as not reusable
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/http/client.py in _tunnel(self)
#     900         response = self.response_class(self.sock, method=self._method)
# --> 901         (version, code, message) = response._read_status()
#     902
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/http/client.py in _read_status(self)
#     276     def _read_status(self):
# --> 277         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278         if len(line) > _MAXLINE:
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='www.douban.com', port=443): Max retries exceeded with url: /group/topic/190942366/ (Caused by ProxyError('Cannot connect to proxy.', TimeoutError(60, 'Operation timed out')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# /var/folders/r1/zv_cgpdj61b8c60j_yk8lx900000gn/T/ipykernel_97999/3945394166.py in <module>
#      11     headers = random.choice(USER_AGENTS) #make a fake user
#      12     proxies = random.choice(PROXY_IPS)
# ---> 13     req = requests.get(grp_dis_list[i], proxies=proxies, headers=headers)
#      14     soup = BeautifulSoup(req.text,"html.parser")
#      15     print("Connect to: " + str(proxies))
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/nlpminiproject/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     508
#     509             if isinstance(e.reason, _ProxyError):
# --> 510                 raise ProxyError(e, request=request)
#     511
#     512             if isinstance(e.reason, _SSLError):
#
# ProxyError: HTTPSConnectionPool(host='www.douban.com', port=443): Max retries exceeded with url: /group/topic/190942366/ (Caused by ProxyError('Cannot connect to proxy.', TimeoutError(60, 'Operation timed out')))

# %%
post_df
# Out:
#                               title  \
# 0                  不干啦！不干啦！远离职场PUA！
# 0                      最近买了一本反PUA的书
# 0             被家人精神虐待（2021-11-28更新）
# 0                  曝光广州pua渣男肖欧辰骗财骗色
# 0                     你也经历这样的父母PUA嘛
# 0                       我经常被pua怎么办啊
# 0                        一个PUA十几的高手
# 0                        被朋友pua了怎么办
# 0                         寻求pua经历访谈
# 0                       集体主义pua典型案例
# 0                      思考了一下广告中的PUA
# 0                        对于pua的一些反思
# 0                        思考——如何反PUA
# 0                    今天看了一个pua的聊天记录
# 0             面对父母的控制、强迫和PUA，我该怎么办？
# 0             寝室有人待人忽冷忽热，还有自以为的优越感。
# 0                          我被pua了吗？
# 0  PUA的本质是什么？使用PUA的是男性多还是女性多？谁更有天赋？
# 0                         我怀疑我被PUA了
# 0                         我怀疑我被pua了
# 0                  救命！我被我妈PUA到不敢吃饭了
# 0                 应该开个贴说说我见到的职场pua了
# 0            大家帮我看看是我的问题还是我被PUA了呢？？
# 0         我恋爱被PUA过 然后PUA我的人被我PUA抑郁了
# 0              大家会不会有时候，也发觉自己在pua别人
# 0                      我怀疑我被男朋友pua了
# 0                                 删
# 0                 这个小组太及时了，被打压的快抑郁了
# 0        求助！已经摆脱了朋友的PUA，但是迟迟走不出阴影……
# 0                                 .
#
#                                             link  \
# 0  https://www.douban.com/group/topic/243256679/
# 0  https://www.douban.com/group/topic/254371782/
# 0  https://www.douban.com/group/topic/245062758/
# 0  https://www.douban.com/group/topic/253535322/
# 0  https://www.douban.com/group/topic/248884797/
# 0  https://www.douban.com/group/topic/247144799/
# 0  https://www.douban.com/group/topic/248505785/
# 0  https://www.douban.com/group/topic/252083239/
# 0  https://www.douban.com/group/topic/251368154/
# 0  https://www.douban.com/group/topic/251957475/
# 0  https://www.douban.com/group/topic/251941044/
# 0  https://www.douban.com/group/topic/251850833/
# 0  https://www.douban.com/group/topic/250351690/
# 0  https://www.douban.com/group/topic/250259261/
# 0  https://www.douban.com/group/topic/248698958/
# 0  https://www.douban.com/group/topic/250294313/
# 0  https://www.douban.com/group/topic/247940421/
# 0  https://www.douban.com/group/topic/249905369/
# 0  https://www.douban.com/group/topic/249211569/
# 0  https://www.douban.com/group/topic/248485192/
# 0  https://www.douban.com/group/topic/244074300/
# 0  https://www.douban.com/group/topic/243162095/
# 0  https://www.douban.com/group/topic/244669722/
# 0  https://www.douban.com/group/topic/242945869/
# 0  https://www.douban.com/group/topic/247759645/
# 0  https://www.douban.com/group/topic/247333764/
# 0  https://www.douban.com/group/topic/247360615/
# 0  https://www.douban.com/group/topic/242955074/
# 0  https://www.douban.com/group/topic/246083668/
# 0  https://www.douban.com/group/topic/244770498/
#
#                                            main text  \
# 0  [央企工作四年，目前已提交辞职报告，等待离职中。, —————————————————, 2...
# 0                          [之遭到严重PUA，。推荐这本书，等看完在来小组]
# 0  [不知道要怎么写，就条列式好了：, 没了。如果看不懂，就算了。, 然后很吊诡的是，我姐和我认...
# 0  [曝光广州深圳嘉禾望岗pua渣男肖欧辰骗财骗色，身高179年龄和每个人说的都不一样88-90...
# 0  [#这算是被父母PUA了嚒#, 很感触. 父母近几年一直针对我一直单身这回事. 天知道不是我...
# 0  [我经常被人pua，想起来都气，这个人还是我亲哥。, 例如我发照片去朋友圈，我亲哥会私信我说...
# 0  [这是一个男生。我也是男生。我从来没有想到会遇到这样一个对同性PUA的人。, 这是我遇见的唯...
# 0  [lz是高中生，同桌是朋友，有几件事一直让我耿耿于怀，一次是我在纸上写字，她莫明奇妙凑过来看...
# 0  [新传研究生，想寻求被pua过的朋友进行一次访谈，访谈的个人信息及内容全程保密，仅做学术研究...
# 0                              [,  个人觉得是集体主义pua典型案例]
# 0  [ 看到椰汁的魔性包装，想起了椰汁以前的辣眼广告，不禁思考了一下广告中好像也存在PUA的形式...
# 0  [曾经被一个男人pua了很久，他让我相信我自己是个垃圾，我无可救药，我人生完蛋了。, 但是我...
# 0  [最重要的前提是：独立，以及“我本位”, 思想独立、经济独立, 凡是以自我为中心，以自己利益...
# 0  [骂女孩子露肉就是什么公共女朋友，骂的那话恶心死了。后来女孩子还自杀了，UU们，如果你们遇到...
# 0  [先说一点，我是家里的独生子，父母很爱我，这点我不否认。, 但是，父母关心的方式，我实在接受...
# 0  [寝室有个女的，姑且叫A，家境小康，平时总爱拿名牌来贬低同班同学，也背地里贬低过lz。lz家...
# 0  [相识一年，最初对他印象极好，甚至可以说很崇拜，自认为对他是一见钟情。现在越来越抑郁，睡眠变...
# 0  [1、以推拉、进挪、dhv等技术为核心的泡妞理论, 2、通过各方面打压（推）使人缺乏自信的手...
# 0  [我老公性格比较暴躁，什么事都需要听他的，不依着就会发很脾气，每次吵架以他发火我哭着妥协结束...
# 0  [情况大概是这样，大二的时候因为一个活动和班里一个同学变成了比较亲近的朋友，会一起上课、做小...
# 0  [楼主是大二学生，因为学校的宿舍条件太差了（没有洗澡的地方，洗澡都是提着水桶在坑上洗）想在外...
# 0                                                [1]
# 0  [我在去年年底12月30号入职一家公司， 那时候跟他不是一个部门也没有交集 都不知道这个人的...
# 0  [正常人怎么会想着主动PUA别人？, 尤其是恋爱关系中, 恋爱中的男人如果试图PUA你，说明...
# 0  [不知道我对pua的理解对不对, 我觉得就是情感操控, 利用在乎别人对自己的在乎，达到自己想...
# 0  [我感觉好像被男朋友pua了\n\r   因为受政策影响，我在三个月前失业了，这期间我真的比...
# 0                                                [删]
# 0  [在一起八个月，拉拉，女朋友经常打压我，最近，分手了，但是我有点抑郁倾向，现在对什么都不感兴...
# 0  [简单地说就是我年少不懂事结识了一个网友，也面基了几次，就真把她当朋友了。因为她年龄比我大，...
# 0                                              [\n.]
#
#                                           reply text
# 0  [灌酒不能忍。这叔叔也是太差了。, 灌酒不能忍。这叔叔也是太差了。, 看到一半就看不下去了，...
# 0                                                 []
# 0  [只有下定决心逃出去，再跟父母断绝联系，否则一辈子都逃不掉，而且这种情况，就算结婚了，也会被...
# 0                                                 []
# 0                          [根本就不爱你，别做梦了，你只是个不听话的工具人]
# 0  [不能解释，不给他眼神就行了，越搭理越来劲。他质问你为什么不回复的时候就说“我还以为”。\n...
# 0      [控制自己，远离他吧, 别纠结了，打一仗，再有一次再打，直到他不敢跟你说话为止，就是惯的]
# 0                                 [别怕，不满一定要说出来，不服就干]
# 0                         [提醒⏰：請注意保護個人隱私和防範信息被惡意利用。]
# 0                                                 []
# 0                                                 []
# 0                                                 []
# 0                                                 []
# 0  [真的！女孩子千万不要受气！对象说你你就说回去！大不了分手走人断联！永远把自己摆在第一位！自...
# 0  [既然经济独立，住在外地，就减少打电话减少视频。说到你不爱听的话就立刻挂断, 不要住在一起。...
# 0                                                 []
# 0  [我从看到第一条就在想 该怎么把让他滚这三个字说的委婉点……, 而且我不能懂，为啥读个博士就...
# 0                [感觉生活中使用pua的男的更多，男老师、男上司，还有各种男朋友老公]
# 0  [您结婚的目的是？, 不仅仅是被pua吧, 一月五百零花钱？楼主有工作吗，先实现经济独立吧,...
# 0  [下定决心远离她吧！一个正常的好朋友是会给你提供好的情绪帮助。\n假使你这个朋友觉得你的演讲...
# 0  [光看聊天语气是你妈有问题，一个人不能对任何人这样说话的。尽量自己攒钱远离你妈吧，不要试图和...
# 0  [好上司常反省自己，鼓励他人，降卑自己，托住他人。反之如楼所说，就是折磨人，处处让人受打击，...
# 0  [一个男的，就因为借着交往的名义，就强迫拥抱，强迫叫老公，有时候还强迫摸胸。LZ你这不是看得...
# 0  [是的，这个不分性别，一般是强势的一方容易PUA弱势的一方，甚至双方都没意识到是PUA, 我...
# 0  [那我不是。当意识到自己在pua 别人的时候 会即刻停止这段关系 或者重新调整自己与对方的相...
# 0                               [他只是不爱你了。, 是呀所以我看开了]
# 0  [你不舒服就算, 两个人的关系让你感到不舒服那就算了吧, PUA者的根本特质是不愿放手。现在...
# 0  [她是啥好处都想占…已婚还出来骗人太恶心了。祝你以后越来越好, 还好分手了，让她去吧，和对象...
# 0                                               [dd]
# 0  [应该是被PUA了，因为你们两的交流并不对等, 应该是被PUA了，因为你们两的交流并不对等,...

# %%
#Write to file
file_name = "DOUBAN_dataset_group03"
post_df.to_csv(file_name + ".tsv", sep = "\t", columns = ["title","link","main text","reply text"], index = False)
